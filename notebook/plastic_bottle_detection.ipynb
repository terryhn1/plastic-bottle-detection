# %%
import torch
import torchvision
from torchvision.models.detection import FasterRCNN_MobileNet_V3_Large_FPN_Weights,\
                                         fasterrcnn_mobilenet_v3_large_fpn, \
                                         SSD300_VGG16_Weights, \
                                         ssd300_vgg16
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torch.utils.data import Dataset, DataLoader

# %%
def create_faster_rcnn_mobilenet_v3():
  weights = FasterRCNN_MobileNet_V3_Large_FPN_Weights.DEFAULT
  model = fasterrcnn_mobilenet_v3_large_fpn(weights = weights)

  # replace classifer
  num_classes = 2

  # get in features
  in_features = model.roi_heads.box_predictor.cls_score.in_features

  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

  return model

# %%
# Read Kaggle JSON File from Google Drive
from google.colab import drive
import os

try:
  # !rmdir ~/.kaggle
  # !mkdir ~/.kaggle
  print("Successfully created kaggle folder")
  drive.mount('/content/drive/')
  # !cp /content/drive/MyDrive/apis/kaggle.json ~/.kaggle/kaggle.json
  print("Succssfully copied kaggle json and now moving it to colab space")
  drive.flush_and_unmount()
except:
  raise Exception("Issue occurred while trying to create Kaggle Folder")
# Out:
# rmdir: failed to remove '/root/.kaggle': No such file or directory
# Successfully created kaggle folder
# Mounted at /content/drive/
# Succssfully copied kaggle json and now moving it to colab space

# %%
# Create Custom Dataset from the Plastic Bottle dataset on Kaggle

import zipfile

# !kaggle datasets download -d siddharthkumarsah/plastic-bottles-image-dataset\

# Unzip the folder
path = 'plastic-bottles-image-dataset.zip'
destination = 'plastic-bottles-image-dataset'

with zipfile.ZipFile(path, 'r') as zip_ref:
  zip_ref.extractall(destination)
# Out:
# Downloading plastic-bottles-image-dataset.zip to /content
# 100% 1.53G/1.53G [01:27<00:00, 21.0MB/s]
# 100% 1.53G/1.53G [01:27<00:00, 18.7MB/s]

# %%
import os
import torch
from PIL import Image

class PlasticBottleDataset(Dataset):

  def __init__(self, root, transforms, train):
    self.root = root
    self.transforms = transforms
    
    # root is the dataset path  'plastic-bottles-images-dataset'
    folder = 'train' if train else 'test'
    self.images = [os.path.join(root, folder, 'images', image_path) for image_path in os.listdir(root / folder  / 'images')]
    self.images.sort()
    self.ground_truths = [os.path.join(root, folder, 'labels', label_path) for label_path in os.listdir(root / folder / 'labels')]
    self.ground_truths.sort()

  def __getitem__(self, idx):
    image_path = self.images[idx]
    ground_truth_path = self.ground_truths[idx]
    img = Image.open(image_path).convert('RGB')

    boxes = []
    with open(ground_truth_path, 'r') as ground_truth:
      for line in ground_truth:
        # Transforms the X, Y, W, H into Xmin, Ymin, Xmax, Ymax
        yolo_format = [float(val) for val in line.split()[1:]]
        
        w = yolo_format[2] * img.width
        h = yolo_format[3] * img.height
        x_min = max(0, ((2 * yolo_format[0] * img.width) - w) / 2)
        y_min = max(0, ((2 * yolo_format[1] * img.height) - h) / 2)
        x_max = min(img.width, x_min + w)
        y_max = min(img.height, y_min + h)

        if y_min == y_max or x_min == x_max:
          continue

        boxes.append([x_min, y_min, x_max, y_max])

    boxes = torch.as_tensor(boxes, dtype = torch.float32)
    if len(boxes) == 0:
      # Issue comes up if no bounding boxes have been found or incorrect measurements given for the bounding box
      # If so, we assume the whole picture is the bounding box
      boxes = torch.as_tensor([[0, 0, img.width, img.height]], dtype = torch.float32)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    labels = torch.ones((len(boxes)), dtype = torch.int64)
    iscrowd = torch.zeros((len(boxes)), dtype = torch.int64)

    image_id = torch.tensor([idx])

    target = {}
    target['boxes'] = boxes
    target['area'] = area
    target['iscrowd'] = iscrowd
    target['image_id'] = image_id
    target['labels'] = labels

    if self.transforms:
      img, target = self.transforms(img,target)
    
    return img, target
  
  def __len__(self):
    return len(self.images)

# %%
## This script downloads the most recent. Website example shows the use of a deprecated version.

# %%shell

# Download TorchVision repo to use some files from
# references/detection
git clone https://github.com/pytorch/vision.git
cd vision

cp references/detection/utils.py ../
cp references/detection/transforms.py ../
cp references/detection/coco_eval.py ../
cp references/detection/engine.py ../
cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 323012, done.
# remote: Counting objects: 100% (983/983), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 323012 (delta 764), reused 952 (delta 743), pack-reused 322029
# Receiving objects: 100% (323012/323012), 654.75 MiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (296810/296810), done.

# %%
import transforms
# create the transforms, simple horizontal flip

def get_transforms(train):
  if train:
    return transforms.Compose([
      transforms.PILToTensor(),
      transforms.ConvertImageDtype(torch.float),
      transforms.RandomHorizontalFlip(0.5)]  
    )
  else:
    return transforms.Compose([
        transforms.PILToTensor(),
        transforms.ConvertImageDtype(torch.float)]
    )

# %%
# set up the dataloaders
import utils

def get_dataloaders(root):
  train_dataset, test_dataset = get_datasets(root)
  
  train_dataloader = DataLoader(train_dataset,
                                batch_size = 2,
                                num_workers = os.cpu_count(),
                                shuffle = True,
                                collate_fn = utils.collate_fn)
  
  test_dataloader = DataLoader(test_dataset,
                               batch_size = 1,
                               num_workers = 0,
                               shuffle = False,
                               collate_fn = utils.collate_fn)
  
  return train_dataloader, test_dataloader

def get_datasets(root):
  train_dataset = PlasticBottleDataset(root,
                                       transforms = get_transforms(train = True),
                                       train = True)
  test_dataset = PlasticBottleDataset(root,
                                      transforms = get_transforms(train = False),
                                      train = False)
  
  return train_dataset, test_dataset

# %%
# set up the optimizer
def get_optim(model):
  params = [param for param in model.parameters() if param.requires_grad]
  optimizer = torch.optim.SGD(params, lr = 0.001, momentum = 0.9000, weight_decay = 0.0005)
  lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer = optimizer,
                                                 step_size = 3,
                                                 gamma = 0.1)
  return optimizer, lr_scheduler

# %%
def model_save_to_drive(model, epoch):

  model_name = f'trash_detection_faster_rcnn_mobilenetv2_epoch_{epoch}.pth'
  model_file = '/content/drive/MyDrive/models/'

  drive.mount('/content/drive/')
  torch.save(model.state_dict(), model_file + model_name)
  drive.flush_and_unmount()

# %%
from engine import train_one_epoch, evaluate
from pathlib import Path
def run():

  # set the device
  device = 'cuda' if torch.cuda.is_available() else 'cpu'

  # create the dataloaders
  root_path = Path(os.getcwd()) / "plastic-bottles-image-dataset" / 'Plastic Bottle Image Dataset'
  train_dataloader, test_dataloader = get_dataloaders(root_path)

  # get the model
  model = create_faster_rcnn_mobilenet_v3().to(device)

  # get the optimizer and learning rate scheduler
  optim, lr_scheduler = get_optim(model)

  # train step
  epochs = 5
  
  for epoch in range(epochs):
    train_one_epoch(model = model,
                    optimizer = optim,
                    data_loader = train_dataloader,
                    device = device,
                    epoch = epoch,
                    print_freq = 10)
    
    lr_scheduler.step()
    evaluate(model = model,
             data_loader = test_dataloader,
             device = device)

    model_save_to_drive(model, epoch)

  return model

# %%
model = run()
# Out:
# Epoch: [0]  [   0/1089]  eta: 0:26:09  lr: 0.000002  loss: 1.6020 (1.6020)  loss_classifier: 0.7861 (0.7861)  loss_box_reg: 0.7116 (0.7116)  loss_objectness: 0.0085 (0.0085)  loss_rpn_box_reg: 0.0959 (0.0959)  time: 1.4416  data: 1.1475  max mem: 1601
# Epoch: [0]  [  10/1089]  eta: 0:08:48  lr: 0.000012  loss: 1.6020 (1.6462)  loss_classifier: 0.7226 (0.7393)  loss_box_reg: 0.5685 (0.4663)  loss_objectness: 0.2330 (0.3642)  loss_rpn_box_reg: 0.0399 (0.0764)  time: 0.4895  data: 0.3236  max mem: 1931
# Epoch: [0]  [  20/1089]  eta: 0:06:54  lr: 0.000022  loss: 1.3572 (1.5275)  loss_classifier: 0.7226 (0.7530)  loss_box_reg: 0.3783 (0.4343)  loss_objectness: 0.1395 (0.2773)  loss_rpn_box_reg: 0.0245 (0.0629)  time: 0.3355  data: 0.1783  max mem: 1931
# Epoch: [0]  [  30/1089]  eta: 0:06:52  lr: 0.000032  loss: 1.2900 (1.4468)  loss_classifier: 0.6510 (0.7054)  loss_box_reg: 0.3440 (0.4195)  loss_objectness: 0.1088 (0.2619)  loss_rpn_box_reg: 0.0299 (0.0599)  time: 0.3347  data: 0.1691  max mem: 1931
# Epoch: [0]  [  40/1089]  eta: 0:05:43  lr: 0.000042  loss: 1.2121 (1.3727)  loss_classifier: 0.5501 (0.6554)  loss_box_reg: 0.4374 (0.4478)  loss_objectness: 0.0280 (0.2188)  loss_rpn_box_reg: 0.0274 (0.0507)  time: 0.2647  data: 0.1184  max mem: 1931
# Epoch: [0]  [  50/1089]  eta: 0:05:21  lr: 0.000052  loss: 1.2193 (1.3904)  loss_classifier: 0.4736 (0.6098)  loss_box_reg: 0.5545 (0.4509)  loss_objectness: 0.0280 (0.2602)  loss_rpn_box_reg: 0.0204 (0.0696)  time: 0.1846  data: 0.0537  max mem: 1931
# Epoch: [0]  [  60/1089]  eta: 0:05:03  lr: 0.000062  loss: 1.2302 (1.3932)  loss_classifier: 0.3408 (0.5641)  loss_box_reg: 0.3483 (0.4300)  loss_objectness: 0.1437 (0.3128)  loss_rpn_box_reg: 0.0332 (0.0863)  time: 0.2265  data: 0.0875  max mem: 1931
# Epoch: [0]  [  70/1089]  eta: 0:04:37  lr: 0.000072  loss: 0.9788 (1.3290)  loss_classifier: 0.3255 (0.5305)  loss_box_reg: 0.2917 (0.4209)  loss_objectness: 0.0912 (0.2915)  loss_rpn_box_reg: 0.0398 (0.0860)  time: 0.1777  data: 0.0492  max mem: 1931
# Epoch: [0]  [  80/1089]  eta: 0:04:20  lr: 0.000082  loss: 0.9290 (1.3035)  loss_classifier: 0.3060 (0.5013)  loss_box_reg: 0.3169 (0.4146)  loss_objectness: 0.0548 (0.2929)  loss_rpn_box_reg: 0.0528 (0.0947)  time: 0.1468  data: 0.0215  max mem: 1931
# Epoch: [0]  [  90/1089]  eta: 0:04:14  lr: 0.000092  loss: 0.9558 (1.2648)  loss_classifier: 0.2866 (0.4786)  loss_box_reg: 0.3608 (0.4090)  loss_objectness: 0.0660 (0.2829)  loss_rpn_box_reg: 0.0553 (0.0944)  time: 0.1910  data: 0.0445  max mem: 1931
# Epoch: [0]  [ 100/1089]  eta: 0:04:35  lr: 0.000102  loss: 0.8269 (1.2262)  loss_classifier: 0.2801 (0.4567)  loss_box_reg: 0.3013 (0.3992)  loss_objectness: 0.1059 (0.2770)  loss_rpn_box_reg: 0.0333 (0.0933)  time: 0.3598  data: 0.1433  max mem: 1931
# Epoch: [0]  [ 110/1089]  eta: 0:04:28  lr: 0.000112  loss: 0.6791 (1.1790)  loss_classifier: 0.2222 (0.4359)  loss_box_reg: 0.2781 (0.3886)  loss_objectness: 0.0968 (0.2631)  loss_rpn_box_reg: 0.0360 (0.0914)  time: 0.3645  data: 0.1555  max mem: 1931
# Epoch: [0]  [ 120/1089]  eta: 0:04:16  lr: 0.000122  loss: 0.6541 (1.1497)  loss_classifier: 0.2296 (0.4220)  loss_box_reg: 0.2781 (0.3851)  loss_objectness: 0.0828 (0.2553)  loss_rpn_box_reg: 0.0352 (0.0873)  time: 0.1973  data: 0.0581  max mem: 1931
# Epoch: [0]  [ 130/1089]  eta: 0:04:19  lr: 0.000132  loss: 0.7418 (1.1208)  loss_classifier: 0.2309 (0.4082)  loss_box_reg: 0.2875 (0.3791)  loss_objectness: 0.1179 (0.2492)  loss_rpn_box_reg: 0.0287 (0.0842)  time: 0.2473  data: 0.0912  max mem: 1931
# Epoch: [0]  [ 140/1089]  eta: 0:04:12  lr: 0.000142  loss: 0.7270 (1.0970)  loss_classifier: 0.2201 (0.3940)  loss_box_reg: 0.2741 (0.3729)  loss_objectness: 0.0797 (0.2440)  loss_rpn_box_reg: 0.0303 (0.0861)  time: 0.2702  data: 0.1084  max mem: 1931
# Epoch: [0]  [ 150/1089]  eta: 0:04:15  lr: 0.000152  loss: 0.6903 (1.0709)  loss_classifier: 0.1991 (0.3809)  loss_box_reg: 0.2764 (0.3656)  loss_objectness: 0.0450 (0.2404)  loss_rpn_box_reg: 0.0303 (0.0840)  time: 0.2825  data: 0.1211  max mem: 1931
# Epoch: [0]  [ 160/1089]  eta: 0:04:09  lr: 0.000162  loss: 0.6942 (1.0621)  loss_classifier: 0.1991 (0.3706)  loss_box_reg: 0.2697 (0.3637)  loss_objectness: 0.1091 (0.2419)  loss_rpn_box_reg: 0.0347 (0.0858)  time: 0.2887  data: 0.1145  max mem: 1931
# Epoch: [0]  [ 170/1089]  eta: 0:04:04  lr: 0.000172  loss: 0.7329 (1.0442)  loss_classifier: 0.1858 (0.3602)  loss_box_reg: 0.2697 (0.3590)  loss_objectness: 0.1575 (0.2389)  loss_rpn_box_reg: 0.0313 (0.0860)  time: 0.2273  data: 0.0691  max mem: 1931
# Epoch: [0]  [ 180/1089]  eta: 0:04:01  lr: 0.000182  loss: 0.5251 (1.0176)  loss_classifier: 0.1630 (0.3484)  loss_box_reg: 0.2270 (0.3496)  loss_objectness: 0.0748 (0.2355)  loss_rpn_box_reg: 0.0192 (0.0841)  time: 0.2422  data: 0.0897  max mem: 1931
# Epoch: [0]  [ 190/1089]  eta: 0:03:54  lr: 0.000192  loss: 0.5213 (0.9949)  loss_classifier: 0.1561 (0.3398)  loss_box_reg: 0.2270 (0.3467)  loss_objectness: 0.0570 (0.2270)  loss_rpn_box_reg: 0.0176 (0.0815)  time: 0.2153  data: 0.0660  max mem: 1931
# Epoch: [0]  [ 200/1089]  eta: 0:03:51  lr: 0.000202  loss: 0.5961 (0.9882)  loss_classifier: 0.1681 (0.3308)  loss_box_reg: 0.2389 (0.3400)  loss_objectness: 0.0570 (0.2299)  loss_rpn_box_reg: 0.0327 (0.0875)  time: 0.2100  data: 0.0596  max mem: 1931
# Epoch: [0]  [ 210/1089]  eta: 0:03:51  lr: 0.000212  loss: 0.5883 (0.9789)  loss_classifier: 0.1668 (0.3235)  loss_box_reg: 0.2027 (0.3356)  loss_objectness: 0.1366 (0.2295)  loss_rpn_box_reg: 0.0627 (0.0904)  time: 0.2810  data: 0.1064  max mem: 1931
# Epoch: [0]  [ 220/1089]  eta: 0:03:48  lr: 0.000222  loss: 0.5883 (0.9686)  loss_classifier: 0.1598 (0.3161)  loss_box_reg: 0.2301 (0.3320)  loss_objectness: 0.1044 (0.2284)  loss_rpn_box_reg: 0.0662 (0.0922)  time: 0.2876  data: 0.1100  max mem: 1931
# Epoch: [0]  [ 230/1089]  eta: 0:03:48  lr: 0.000232  loss: 0.5827 (0.9545)  loss_classifier: 0.1355 (0.3080)  loss_box_reg: 0.1937 (0.3248)  loss_objectness: 0.1345 (0.2291)  loss_rpn_box_reg: 0.0309 (0.0926)  time: 0.2937  data: 0.1161  max mem: 1931
# Epoch: [0]  [ 240/1089]  eta: 0:03:42  lr: 0.000242  loss: 0.4809 (0.9362)  loss_classifier: 0.1222 (0.3004)  loss_box_reg: 0.1817 (0.3201)  loss_objectness: 0.1281 (0.2249)  loss_rpn_box_reg: 0.0238 (0.0907)  time: 0.2538  data: 0.0934  max mem: 1931
# Epoch: [0]  [ 250/1089]  eta: 0:03:43  lr: 0.000252  loss: 0.4711 (0.9175)  loss_classifier: 0.1219 (0.2934)  loss_box_reg: 0.2093 (0.3163)  loss_objectness: 0.0689 (0.2194)  loss_rpn_box_reg: 0.0325 (0.0884)  time: 0.2753  data: 0.1161  max mem: 1931
# Epoch: [0]  [ 260/1089]  eta: 0:03:49  lr: 0.000262  loss: 0.4112 (0.8995)  loss_classifier: 0.1157 (0.2865)  loss_box_reg: 0.1731 (0.3091)  loss_objectness: 0.0627 (0.2166)  loss_rpn_box_reg: 0.0364 (0.0873)  time: 0.4538  data: 0.2396  max mem: 1931
# Epoch: [0]  [ 270/1089]  eta: 0:03:46  lr: 0.000272  loss: 0.4491 (0.8942)  loss_classifier: 0.0926 (0.2797)  loss_box_reg: 0.0911 (0.3044)  loss_objectness: 0.0849 (0.2158)  loss_rpn_box_reg: 0.0315 (0.0944)  time: 0.4112  data: 0.2077  max mem: 1931
# Epoch: [0]  [ 280/1089]  eta: 0:03:44  lr: 0.000282  loss: 0.4372 (0.8793)  loss_classifier: 0.0886 (0.2733)  loss_box_reg: 0.1054 (0.2981)  loss_objectness: 0.0727 (0.2137)  loss_rpn_box_reg: 0.0429 (0.0942)  time: 0.2889  data: 0.1139  max mem: 1931
# Epoch: [0]  [ 290/1089]  eta: 0:03:41  lr: 0.000292  loss: 0.4154 (0.8634)  loss_classifier: 0.0959 (0.2677)  loss_box_reg: 0.1511 (0.2935)  loss_objectness: 0.0682 (0.2096)  loss_rpn_box_reg: 0.0429 (0.0926)  time: 0.2844  data: 0.0989  max mem: 1931
# Epoch: [0]  [ 300/1089]  eta: 0:03:37  lr: 0.000302  loss: 0.4553 (0.8506)  loss_classifier: 0.1135 (0.2629)  loss_box_reg: 0.1632 (0.2908)  loss_objectness: 0.0595 (0.2062)  loss_rpn_box_reg: 0.0194 (0.0907)  time: 0.2537  data: 0.0810  max mem: 1931
# Epoch: [0]  [ 310/1089]  eta: 0:03:38  lr: 0.000312  loss: 0.4553 (0.8377)  loss_classifier: 0.1222 (0.2585)  loss_box_reg: 0.1569 (0.2879)  loss_objectness: 0.0595 (0.2026)  loss_rpn_box_reg: 0.0194 (0.0887)  time: 0.3244  data: 0.1432  max mem: 1931
# Epoch: [0]  [ 320/1089]  eta: 0:03:34  lr: 0.000322  loss: 0.3687 (0.8307)  loss_classifier: 0.0982 (0.2538)  loss_box_reg: 0.1291 (0.2829)  loss_objectness: 0.0625 (0.2014)  loss_rpn_box_reg: 0.0264 (0.0926)  time: 0.3335  data: 0.1500  max mem: 1931
# Epoch: [0]  [ 330/1089]  eta: 0:03:29  lr: 0.000332  loss: 0.4585 (0.8250)  loss_classifier: 0.1072 (0.2504)  loss_box_reg: 0.1479 (0.2799)  loss_objectness: 0.0793 (0.2011)  loss_rpn_box_reg: 0.0512 (0.0936)  time: 0.2010  data: 0.0559  max mem: 1931
# Epoch: [0]  [ 340/1089]  eta: 0:03:25  lr: 0.000342  loss: 0.4892 (0.8155)  loss_classifier: 0.1055 (0.2462)  loss_box_reg: 0.1561 (0.2760)  loss_objectness: 0.0797 (0.2002)  loss_rpn_box_reg: 0.0415 (0.0932)  time: 0.1960  data: 0.0552  max mem: 1931
# Epoch: [0]  [ 350/1089]  eta: 0:03:21  lr: 0.000352  loss: 0.4535 (0.8061)  loss_classifier: 0.1048 (0.2431)  loss_box_reg: 0.1473 (0.2736)  loss_objectness: 0.0929 (0.1973)  loss_rpn_box_reg: 0.0397 (0.0922)  time: 0.2092  data: 0.0611  max mem: 1931
# Epoch: [0]  [ 360/1089]  eta: 0:03:19  lr: 0.000362  loss: 0.3666 (0.7946)  loss_classifier: 0.1048 (0.2396)  loss_box_reg: 0.1235 (0.2697)  loss_objectness: 0.0948 (0.1946)  loss_rpn_box_reg: 0.0250 (0.0907)  time: 0.2479  data: 0.0971  max mem: 1931
# Epoch: [0]  [ 370/1089]  eta: 0:03:17  lr: 0.000372  loss: 0.3986 (0.7886)  loss_classifier: 0.1082 (0.2369)  loss_box_reg: 0.1223 (0.2671)  loss_objectness: 0.0948 (0.1945)  loss_rpn_box_reg: 0.0310 (0.0902)  time: 0.3256  data: 0.1543  max mem: 1931
# Epoch: [0]  [ 380/1089]  eta: 0:03:13  lr: 0.000382  loss: 0.4659 (0.7798)  loss_classifier: 0.1127 (0.2342)  loss_box_reg: 0.1224 (0.2644)  loss_objectness: 0.0819 (0.1925)  loss_rpn_box_reg: 0.0345 (0.0886)  time: 0.2790  data: 0.1056  max mem: 1931
# Epoch: [0]  [ 390/1089]  eta: 0:03:10  lr: 0.000392  loss: 0.3334 (0.7716)  loss_classifier: 0.0953 (0.2313)  loss_box_reg: 0.1224 (0.2611)  loss_objectness: 0.0447 (0.1905)  loss_rpn_box_reg: 0.0210 (0.0887)  time: 0.2335  data: 0.0690  max mem: 1931
# Epoch: [0]  [ 400/1089]  eta: 0:03:06  lr: 0.000402  loss: 0.3133 (0.7601)  loss_classifier: 0.0953 (0.2278)  loss_box_reg: 0.0866 (0.2574)  loss_objectness: 0.0447 (0.1878)  loss_rpn_box_reg: 0.0214 (0.0871)  time: 0.2252  data: 0.0739  max mem: 1931
# Epoch: [0]  [ 410/1089]  eta: 0:03:03  lr: 0.000412  loss: 0.3194 (0.7517)  loss_classifier: 0.0969 (0.2248)  loss_box_reg: 0.0964 (0.2542)  loss_objectness: 0.0882 (0.1866)  loss_rpn_box_reg: 0.0214 (0.0861)  time: 0.2103  data: 0.0646  max mem: 1931
# Epoch: [0]  [ 420/1089]  eta: 0:03:00  lr: 0.000422  loss: 0.4344 (0.7516)  loss_classifier: 0.0901 (0.2217)  loss_box_reg: 0.1266 (0.2514)  loss_objectness: 0.1018 (0.1893)  loss_rpn_box_reg: 0.0278 (0.0893)  time: 0.2337  data: 0.0733  max mem: 1931
# Epoch: [0]  [ 430/1089]  eta: 0:02:58  lr: 0.000432  loss: 0.4001 (0.7448)  loss_classifier: 0.0901 (0.2189)  loss_box_reg: 0.1105 (0.2489)  loss_objectness: 0.0741 (0.1876)  loss_rpn_box_reg: 0.0212 (0.0895)  time: 0.2977  data: 0.1102  max mem: 1931
# Epoch: [0]  [ 440/1089]  eta: 0:02:55  lr: 0.000442  loss: 0.2914 (0.7351)  loss_classifier: 0.0903 (0.2159)  loss_box_reg: 0.1125 (0.2460)  loss_objectness: 0.0592 (0.1853)  loss_rpn_box_reg: 0.0187 (0.0879)  time: 0.3094  data: 0.1272  max mem: 1931
# Epoch: [0]  [ 450/1089]  eta: 0:02:52  lr: 0.000452  loss: 0.3306 (0.7339)  loss_classifier: 0.0903 (0.2142)  loss_box_reg: 0.1082 (0.2438)  loss_objectness: 0.0923 (0.1866)  loss_rpn_box_reg: 0.0234 (0.0894)  time: 0.2458  data: 0.0920  max mem: 1931
# Epoch: [0]  [ 460/1089]  eta: 0:02:48  lr: 0.000462  loss: 0.3748 (0.7264)  loss_classifier: 0.0769 (0.2119)  loss_box_reg: 0.0941 (0.2413)  loss_objectness: 0.0824 (0.1842)  loss_rpn_box_reg: 0.0309 (0.0891)  time: 0.1947  data: 0.0500  max mem: 1931
# Epoch: [0]  [ 470/1089]  eta: 0:02:44  lr: 0.000472  loss: 0.3429 (0.7208)  loss_classifier: 0.0939 (0.2098)  loss_box_reg: 0.0976 (0.2388)  loss_objectness: 0.0676 (0.1828)  loss_rpn_box_reg: 0.0370 (0.0895)  time: 0.1769  data: 0.0373  max mem: 1931
# Epoch: [0]  [ 480/1089]  eta: 0:02:43  lr: 0.000482  loss: 0.3449 (0.7138)  loss_classifier: 0.1027 (0.2076)  loss_box_reg: 0.0976 (0.2366)  loss_objectness: 0.0610 (0.1806)  loss_rpn_box_reg: 0.0354 (0.0890)  time: 0.3007  data: 0.1130  max mem: 1931
# Epoch: [0]  [ 490/1089]  eta: 0:02:41  lr: 0.000492  loss: 0.3419 (0.7068)  loss_classifier: 0.0945 (0.2057)  loss_box_reg: 0.1359 (0.2347)  loss_objectness: 0.0468 (0.1787)  loss_rpn_box_reg: 0.0198 (0.0878)  time: 0.3740  data: 0.1602  max mem: 1931
# Epoch: [0]  [ 500/1089]  eta: 0:02:38  lr: 0.000501  loss: 0.3499 (0.7033)  loss_classifier: 0.1200 (0.2039)  loss_box_reg: 0.1189 (0.2326)  loss_objectness: 0.0535 (0.1784)  loss_rpn_box_reg: 0.0233 (0.0884)  time: 0.2897  data: 0.1230  max mem: 1931
# Epoch: [0]  [ 510/1089]  eta: 0:02:35  lr: 0.000511  loss: 0.4180 (0.7000)  loss_classifier: 0.0826 (0.2014)  loss_box_reg: 0.0988 (0.2305)  loss_objectness: 0.0848 (0.1775)  loss_rpn_box_reg: 0.0404 (0.0906)  time: 0.2358  data: 0.0861  max mem: 1931
# Epoch: [0]  [ 520/1089]  eta: 0:02:31  lr: 0.000521  loss: 0.3753 (0.6947)  loss_classifier: 0.0814 (0.1995)  loss_box_reg: 0.1046 (0.2286)  loss_objectness: 0.0848 (0.1760)  loss_rpn_box_reg: 0.0324 (0.0907)  time: 0.1946  data: 0.0436  max mem: 1931
# Epoch: [0]  [ 530/1089]  eta: 0:02:28  lr: 0.000531  loss: 0.2622 (0.6894)  loss_classifier: 0.0666 (0.1974)  loss_box_reg: 0.0727 (0.2262)  loss_objectness: 0.0725 (0.1752)  loss_rpn_box_reg: 0.0231 (0.0907)  time: 0.2000  data: 0.0359  max mem: 1931
# Epoch: [0]  [ 540/1089]  eta: 0:02:26  lr: 0.000541  loss: 0.3285 (0.6853)  loss_classifier: 0.0813 (0.1953)  loss_box_reg: 0.0727 (0.2241)  loss_objectness: 0.0854 (0.1750)  loss_rpn_box_reg: 0.0231 (0.0909)  time: 0.2647  data: 0.0747  max mem: 1931
# Epoch: [0]  [ 550/1089]  eta: 0:02:23  lr: 0.000551  loss: 0.3426 (0.6811)  loss_classifier: 0.0815 (0.1936)  loss_box_reg: 0.1008 (0.2224)  loss_objectness: 0.0968 (0.1751)  loss_rpn_box_reg: 0.0292 (0.0900)  time: 0.2767  data: 0.1019  max mem: 1931
# Epoch: [0]  [ 560/1089]  eta: 0:02:20  lr: 0.000561  loss: 0.3636 (0.6776)  loss_classifier: 0.0777 (0.1915)  loss_box_reg: 0.0863 (0.2204)  loss_objectness: 0.0896 (0.1747)  loss_rpn_box_reg: 0.0292 (0.0910)  time: 0.2479  data: 0.0895  max mem: 1931
# Epoch: [0]  [ 570/1089]  eta: 0:02:17  lr: 0.000571  loss: 0.3613 (0.6723)  loss_classifier: 0.0733 (0.1898)  loss_box_reg: 0.0849 (0.2190)  loss_objectness: 0.0876 (0.1731)  loss_rpn_box_reg: 0.0491 (0.0904)  time: 0.2220  data: 0.0705  max mem: 1931
# Epoch: [0]  [ 580/1089]  eta: 0:02:14  lr: 0.000581  loss: 0.3489 (0.6681)  loss_classifier: 0.0712 (0.1880)  loss_box_reg: 0.0877 (0.2171)  loss_objectness: 0.0872 (0.1722)  loss_rpn_box_reg: 0.0274 (0.0908)  time: 0.2261  data: 0.0695  max mem: 1931
# Epoch: [0]  [ 590/1089]  eta: 0:02:12  lr: 0.000591  loss: 0.3018 (0.6643)  loss_classifier: 0.0873 (0.1871)  loss_box_reg: 0.0917 (0.2162)  loss_objectness: 0.0639 (0.1709)  loss_rpn_box_reg: 0.0311 (0.0901)  time: 0.2858  data: 0.1183  max mem: 1931
# Epoch: [0]  [ 600/1089]  eta: 0:02:10  lr: 0.000601  loss: 0.2691 (0.6595)  loss_classifier: 0.0765 (0.1851)  loss_box_reg: 0.0792 (0.2140)  loss_objectness: 0.0639 (0.1699)  loss_rpn_box_reg: 0.0311 (0.0906)  time: 0.3022  data: 0.1354  max mem: 1931
# Epoch: [0]  [ 610/1089]  eta: 0:02:06  lr: 0.000611  loss: 0.3178 (0.6571)  loss_classifier: 0.0762 (0.1838)  loss_box_reg: 0.0793 (0.2126)  loss_objectness: 0.0891 (0.1694)  loss_rpn_box_reg: 0.0326 (0.0912)  time: 0.2395  data: 0.0717  max mem: 1931
# Epoch: [0]  [ 620/1089]  eta: 0:02:04  lr: 0.000621  loss: 0.4133 (0.6563)  loss_classifier: 0.1103 (0.1830)  loss_box_reg: 0.1240 (0.2117)  loss_objectness: 0.0942 (0.1701)  loss_rpn_box_reg: 0.0495 (0.0914)  time: 0.2319  data: 0.0606  max mem: 1931
# Epoch: [0]  [ 630/1089]  eta: 0:02:01  lr: 0.000631  loss: 0.3167 (0.6513)  loss_classifier: 0.1057 (0.1815)  loss_box_reg: 0.0949 (0.2099)  loss_objectness: 0.0735 (0.1687)  loss_rpn_box_reg: 0.0398 (0.0912)  time: 0.2736  data: 0.0954  max mem: 1931
# Epoch: [0]  [ 640/1089]  eta: 0:01:58  lr: 0.000641  loss: 0.3020 (0.6476)  loss_classifier: 0.0856 (0.1802)  loss_box_reg: 0.0949 (0.2087)  loss_objectness: 0.0653 (0.1682)  loss_rpn_box_reg: 0.0386 (0.0904)  time: 0.2598  data: 0.0935  max mem: 1931
# Epoch: [0]  [ 650/1089]  eta: 0:01:55  lr: 0.000651  loss: 0.2803 (0.6447)  loss_classifier: 0.0710 (0.1785)  loss_box_reg: 0.1050 (0.2070)  loss_objectness: 0.0778 (0.1678)  loss_rpn_box_reg: 0.0203 (0.0914)  time: 0.2089  data: 0.0530  max mem: 1931
# Epoch: [0]  [ 660/1089]  eta: 0:01:53  lr: 0.000661  loss: 0.2661 (0.6393)  loss_classifier: 0.0692 (0.1771)  loss_box_reg: 0.0935 (0.2057)  loss_objectness: 0.0504 (0.1662)  loss_rpn_box_reg: 0.0183 (0.0903)  time: 0.2486  data: 0.0924  max mem: 1931
# Epoch: [0]  [ 670/1089]  eta: 0:01:50  lr: 0.000671  loss: 0.2947 (0.6357)  loss_classifier: 0.0894 (0.1762)  loss_box_reg: 0.0935 (0.2044)  loss_objectness: 0.0622 (0.1655)  loss_rpn_box_reg: 0.0183 (0.0897)  time: 0.2386  data: 0.0972  max mem: 1931
# Epoch: [0]  [ 680/1089]  eta: 0:01:46  lr: 0.000681  loss: 0.3336 (0.6318)  loss_classifier: 0.0865 (0.1750)  loss_box_reg: 0.1049 (0.2031)  loss_objectness: 0.0622 (0.1643)  loss_rpn_box_reg: 0.0220 (0.0895)  time: 0.1626  data: 0.0315  max mem: 1931
# Epoch: [0]  [ 690/1089]  eta: 0:01:44  lr: 0.000691  loss: 0.3012 (0.6282)  loss_classifier: 0.0763 (0.1741)  loss_box_reg: 0.1154 (0.2024)  loss_objectness: 0.0497 (0.1631)  loss_rpn_box_reg: 0.0152 (0.0886)  time: 0.2061  data: 0.0673  max mem: 1931
# Epoch: [0]  [ 700/1089]  eta: 0:01:41  lr: 0.000701  loss: 0.3308 (0.6250)  loss_classifier: 0.0991 (0.1735)  loss_box_reg: 0.1442 (0.2018)  loss_objectness: 0.0363 (0.1619)  loss_rpn_box_reg: 0.0119 (0.0878)  time: 0.2538  data: 0.1027  max mem: 1931
# Epoch: [0]  [ 710/1089]  eta: 0:01:38  lr: 0.000711  loss: 0.3308 (0.6218)  loss_classifier: 0.0991 (0.1726)  loss_box_reg: 0.1235 (0.2004)  loss_objectness: 0.0305 (0.1610)  loss_rpn_box_reg: 0.0119 (0.0879)  time: 0.2154  data: 0.0648  max mem: 1931
# Epoch: [0]  [ 720/1089]  eta: 0:01:36  lr: 0.000721  loss: 0.3518 (0.6197)  loss_classifier: 0.1020 (0.1717)  loss_box_reg: 0.0948 (0.1992)  loss_objectness: 0.0997 (0.1611)  loss_rpn_box_reg: 0.0113 (0.0877)  time: 0.2694  data: 0.1032  max mem: 1931
# Epoch: [0]  [ 730/1089]  eta: 0:01:34  lr: 0.000731  loss: 0.4388 (0.6183)  loss_classifier: 0.1128 (0.1711)  loss_box_reg: 0.1016 (0.1985)  loss_objectness: 0.1102 (0.1607)  loss_rpn_box_reg: 0.0326 (0.0881)  time: 0.3586  data: 0.1691  max mem: 1931
# Epoch: [0]  [ 740/1089]  eta: 0:01:31  lr: 0.000741  loss: 0.4135 (0.6153)  loss_classifier: 0.1071 (0.1703)  loss_box_reg: 0.1085 (0.1979)  loss_objectness: 0.0921 (0.1599)  loss_rpn_box_reg: 0.0275 (0.0872)  time: 0.3233  data: 0.1534  max mem: 1931
# Epoch: [0]  [ 750/1089]  eta: 0:01:28  lr: 0.000751  loss: 0.3132 (0.6117)  loss_classifier: 0.1033 (0.1693)  loss_box_reg: 0.0933 (0.1967)  loss_objectness: 0.0803 (0.1590)  loss_rpn_box_reg: 0.0253 (0.0866)  time: 0.2358  data: 0.0877  max mem: 1931
# Epoch: [0]  [ 760/1089]  eta: 0:01:25  lr: 0.000761  loss: 0.3008 (0.6075)  loss_classifier: 0.0827 (0.1682)  loss_box_reg: 0.0910 (0.1954)  loss_objectness: 0.0614 (0.1580)  loss_rpn_box_reg: 0.0200 (0.0859)  time: 0.1750  data: 0.0314  max mem: 1931
# Epoch: [0]  [ 770/1089]  eta: 0:01:23  lr: 0.000771  loss: 0.2935 (0.6070)  loss_classifier: 0.0754 (0.1676)  loss_box_reg: 0.0951 (0.1941)  loss_objectness: 0.0694 (0.1586)  loss_rpn_box_reg: 0.0200 (0.0867)  time: 0.3042  data: 0.1172  max mem: 1931
# Epoch: [0]  [ 780/1089]  eta: 0:01:21  lr: 0.000781  loss: 0.3144 (0.6037)  loss_classifier: 0.0950 (0.1669)  loss_box_reg: 0.0951 (0.1931)  loss_objectness: 0.0528 (0.1575)  loss_rpn_box_reg: 0.0239 (0.0863)  time: 0.3792  data: 0.1736  max mem: 1931
# Epoch: [0]  [ 790/1089]  eta: 0:01:19  lr: 0.000791  loss: 0.3423 (0.6008)  loss_classifier: 0.0950 (0.1660)  loss_box_reg: 0.0960 (0.1922)  loss_objectness: 0.0475 (0.1567)  loss_rpn_box_reg: 0.0200 (0.0858)  time: 0.3118  data: 0.1268  max mem: 1931
# Epoch: [0]  [ 800/1089]  eta: 0:01:16  lr: 0.000801  loss: 0.3231 (0.5989)  loss_classifier: 0.1030 (0.1656)  loss_box_reg: 0.0933 (0.1914)  loss_objectness: 0.0698 (0.1565)  loss_rpn_box_reg: 0.0250 (0.0854)  time: 0.2619  data: 0.0886  max mem: 1931
# Epoch: [0]  [ 810/1089]  eta: 0:01:13  lr: 0.000811  loss: 0.2858 (0.5951)  loss_classifier: 0.1030 (0.1648)  loss_box_reg: 0.1019 (0.1905)  loss_objectness: 0.0352 (0.1550)  loss_rpn_box_reg: 0.0229 (0.0848)  time: 0.2486  data: 0.0855  max mem: 1931
# Epoch: [0]  [ 820/1089]  eta: 0:01:11  lr: 0.000821  loss: 0.3156 (0.5931)  loss_classifier: 0.0889 (0.1639)  loss_box_reg: 0.1019 (0.1894)  loss_objectness: 0.0323 (0.1550)  loss_rpn_box_reg: 0.0203 (0.0847)  time: 0.3065  data: 0.1114  max mem: 1931
# Epoch: [0]  [ 830/1089]  eta: 0:01:08  lr: 0.000831  loss: 0.3156 (0.5906)  loss_classifier: 0.0752 (0.1630)  loss_box_reg: 0.0876 (0.1883)  loss_objectness: 0.0622 (0.1543)  loss_rpn_box_reg: 0.0276 (0.0850)  time: 0.2899  data: 0.1064  max mem: 1931
# Epoch: [0]  [ 840/1089]  eta: 0:01:05  lr: 0.000841  loss: 0.2846 (0.5874)  loss_classifier: 0.0770 (0.1621)  loss_box_reg: 0.0939 (0.1873)  loss_objectness: 0.0470 (0.1534)  loss_rpn_box_reg: 0.0397 (0.0847)  time: 0.2258  data: 0.0787  max mem: 1931
# Epoch: [0]  [ 850/1089]  eta: 0:01:03  lr: 0.000851  loss: 0.2752 (0.5861)  loss_classifier: 0.0770 (0.1612)  loss_box_reg: 0.0947 (0.1862)  loss_objectness: 0.0435 (0.1534)  loss_rpn_box_reg: 0.0249 (0.0853)  time: 0.2556  data: 0.0980  max mem: 1931
# Epoch: [0]  [ 860/1089]  eta: 0:01:00  lr: 0.000861  loss: 0.3562 (0.5841)  loss_classifier: 0.0972 (0.1606)  loss_box_reg: 0.1107 (0.1855)  loss_objectness: 0.0404 (0.1529)  loss_rpn_box_reg: 0.0263 (0.0852)  time: 0.2885  data: 0.1053  max mem: 1931
# Epoch: [0]  [ 870/1089]  eta: 0:00:58  lr: 0.000871  loss: 0.3882 (0.5838)  loss_classifier: 0.0972 (0.1600)  loss_box_reg: 0.0734 (0.1844)  loss_objectness: 0.0926 (0.1533)  loss_rpn_box_reg: 0.0263 (0.0861)  time: 0.2969  data: 0.0961  max mem: 1931
# Epoch: [0]  [ 880/1089]  eta: 0:00:55  lr: 0.000881  loss: 0.3676 (0.5813)  loss_classifier: 0.0800 (0.1593)  loss_box_reg: 0.0864 (0.1836)  loss_objectness: 0.0926 (0.1526)  loss_rpn_box_reg: 0.0251 (0.0858)  time: 0.3264  data: 0.1429  max mem: 1931
# Epoch: [0]  [ 890/1089]  eta: 0:00:52  lr: 0.000891  loss: 0.3231 (0.5805)  loss_classifier: 0.0808 (0.1591)  loss_box_reg: 0.0879 (0.1832)  loss_objectness: 0.0935 (0.1524)  loss_rpn_box_reg: 0.0237 (0.0858)  time: 0.2365  data: 0.0922  max mem: 1931
# Epoch: [0]  [ 900/1089]  eta: 0:00:49  lr: 0.000901  loss: 0.3602 (0.5788)  loss_classifier: 0.0781 (0.1584)  loss_box_reg: 0.0879 (0.1826)  loss_objectness: 0.0935 (0.1521)  loss_rpn_box_reg: 0.0437 (0.0857)  time: 0.1822  data: 0.0442  max mem: 1931
# Epoch: [0]  [ 910/1089]  eta: 0:00:47  lr: 0.000911  loss: 0.4368 (0.5778)  loss_classifier: 0.0849 (0.1580)  loss_box_reg: 0.1049 (0.1820)  loss_objectness: 0.0915 (0.1521)  loss_rpn_box_reg: 0.0262 (0.0858)  time: 0.2377  data: 0.0848  max mem: 1931
# Epoch: [0]  [ 920/1089]  eta: 0:00:44  lr: 0.000921  loss: 0.3477 (0.5760)  loss_classifier: 0.0920 (0.1573)  loss_box_reg: 0.0731 (0.1807)  loss_objectness: 0.0967 (0.1522)  loss_rpn_box_reg: 0.0258 (0.0858)  time: 0.2334  data: 0.0760  max mem: 1931
# Epoch: [0]  [ 930/1089]  eta: 0:00:41  lr: 0.000931  loss: 0.3096 (0.5734)  loss_classifier: 0.0784 (0.1566)  loss_box_reg: 0.0749 (0.1798)  loss_objectness: 0.0754 (0.1514)  loss_rpn_box_reg: 0.0473 (0.0856)  time: 0.2544  data: 0.0730  max mem: 1931
# Epoch: [0]  [ 940/1089]  eta: 0:00:39  lr: 0.000941  loss: 0.3096 (0.5709)  loss_classifier: 0.0939 (0.1560)  loss_box_reg: 0.0842 (0.1792)  loss_objectness: 0.0460 (0.1506)  loss_rpn_box_reg: 0.0411 (0.0851)  time: 0.2658  data: 0.0802  max mem: 1931
# Epoch: [0]  [ 950/1089]  eta: 0:00:36  lr: 0.000951  loss: 0.3112 (0.5690)  loss_classifier: 0.0746 (0.1552)  loss_box_reg: 0.0842 (0.1784)  loss_objectness: 0.0385 (0.1504)  loss_rpn_box_reg: 0.0235 (0.0851)  time: 0.2382  data: 0.0736  max mem: 1931
# Epoch: [0]  [ 960/1089]  eta: 0:00:33  lr: 0.000961  loss: 0.2206 (0.5663)  loss_classifier: 0.0611 (0.1545)  loss_box_reg: 0.0829 (0.1775)  loss_objectness: 0.0350 (0.1496)  loss_rpn_box_reg: 0.0235 (0.0847)  time: 0.2073  data: 0.0591  max mem: 1931
# Epoch: [0]  [ 970/1089]  eta: 0:00:31  lr: 0.000971  loss: 0.2121 (0.5632)  loss_classifier: 0.0632 (0.1538)  loss_box_reg: 0.0606 (0.1766)  loss_objectness: 0.0342 (0.1487)  loss_rpn_box_reg: 0.0184 (0.0841)  time: 0.1896  data: 0.0535  max mem: 1931
# Epoch: [0]  [ 980/1089]  eta: 0:00:28  lr: 0.000981  loss: 0.2598 (0.5634)  loss_classifier: 0.0899 (0.1537)  loss_box_reg: 0.1287 (0.1770)  loss_objectness: 0.0342 (0.1486)  loss_rpn_box_reg: 0.0184 (0.0840)  time: 0.2406  data: 0.0924  max mem: 1931
# Epoch: [0]  [ 990/1089]  eta: 0:00:25  lr: 0.000991  loss: 0.3626 (0.5613)  loss_classifier: 0.0991 (0.1531)  loss_box_reg: 0.1544 (0.1765)  loss_objectness: 0.0361 (0.1479)  loss_rpn_box_reg: 0.0265 (0.0838)  time: 0.2429  data: 0.0790  max mem: 1931
# Epoch: [0]  [1000/1089]  eta: 0:00:23  lr: 0.001000  loss: 0.3486 (0.5605)  loss_classifier: 0.0915 (0.1526)  loss_box_reg: 0.1209 (0.1761)  loss_objectness: 0.0576 (0.1476)  loss_rpn_box_reg: 0.0265 (0.0842)  time: 0.3103  data: 0.1238  max mem: 1931
# Epoch: [0]  [1010/1089]  eta: 0:00:20  lr: 0.001000  loss: 0.4108 (0.5609)  loss_classifier: 0.0824 (0.1520)  loss_box_reg: 0.0886 (0.1753)  loss_objectness: 0.1146 (0.1484)  loss_rpn_box_reg: 0.0592 (0.0851)  time: 0.3576  data: 0.1668  max mem: 1931
# Epoch: [0]  [1020/1089]  eta: 0:00:18  lr: 0.001000  loss: 0.2531 (0.5577)  loss_classifier: 0.0676 (0.1513)  loss_box_reg: 0.0742 (0.1743)  loss_objectness: 0.0772 (0.1476)  loss_rpn_box_reg: 0.0287 (0.0845)  time: 0.2636  data: 0.0835  max mem: 1931
# Epoch: [0]  [1030/1089]  eta: 0:00:15  lr: 0.001000  loss: 0.2412 (0.5555)  loss_classifier: 0.0730 (0.1507)  loss_box_reg: 0.0751 (0.1735)  loss_objectness: 0.0540 (0.1470)  loss_rpn_box_reg: 0.0191 (0.0842)  time: 0.2464  data: 0.0667  max mem: 1931
# Epoch: [0]  [1040/1089]  eta: 0:00:12  lr: 0.001000  loss: 0.2846 (0.5534)  loss_classifier: 0.0709 (0.1499)  loss_box_reg: 0.0751 (0.1727)  loss_objectness: 0.0666 (0.1467)  loss_rpn_box_reg: 0.0378 (0.0841)  time: 0.3030  data: 0.1231  max mem: 1931
# Epoch: [0]  [1050/1089]  eta: 0:00:10  lr: 0.001000  loss: 0.3106 (0.5519)  loss_classifier: 0.0625 (0.1493)  loss_box_reg: 0.0797 (0.1720)  loss_objectness: 0.0771 (0.1462)  loss_rpn_box_reg: 0.0378 (0.0844)  time: 0.3374  data: 0.1563  max mem: 1931
# Epoch: [0]  [1060/1089]  eta: 0:00:07  lr: 0.001000  loss: 0.3404 (0.5505)  loss_classifier: 0.0963 (0.1489)  loss_box_reg: 0.0797 (0.1714)  loss_objectness: 0.0602 (0.1459)  loss_rpn_box_reg: 0.0315 (0.0842)  time: 0.2983  data: 0.1259  max mem: 1931
# Epoch: [0]  [1070/1089]  eta: 0:00:05  lr: 0.001000  loss: 0.3390 (0.5497)  loss_classifier: 0.1043 (0.1489)  loss_box_reg: 0.1063 (0.1712)  loss_objectness: 0.0575 (0.1456)  loss_rpn_box_reg: 0.0289 (0.0840)  time: 0.2934  data: 0.1037  max mem: 1931
# Epoch: [0]  [1080/1089]  eta: 0:00:02  lr: 0.001000  loss: 0.2842 (0.5474)  loss_classifier: 0.0853 (0.1483)  loss_box_reg: 0.1201 (0.1707)  loss_objectness: 0.0374 (0.1447)  loss_rpn_box_reg: 0.0174 (0.0837)  time: 0.3612  data: 0.1686  max mem: 1931
# Epoch: [0]  [1088/1089]  eta: 0:00:00  lr: 0.001000  loss: 0.3180 (0.5464)  loss_classifier: 0.0926 (0.1480)  loss_box_reg: 0.1219 (0.1704)  loss_objectness: 0.0470 (0.1444)  loss_rpn_box_reg: 0.0332 (0.0836)  time: 0.3227  data: 0.1490  max mem: 1931
# Epoch: [0] Total time: 0:04:49 (0.2663 s / it)
# creating index...
# index created!
# Test:  [  0/648]  eta: 0:00:26  model_time: 0.0330 (0.0330)  evaluator_time: 0.0013 (0.0013)  time: 0.0407  data: 0.0056  max mem: 1931
# Test:  [100/648]  eta: 0:00:18  model_time: 0.0223 (0.0226)  evaluator_time: 0.0012 (0.0013)  time: 0.0489  data: 0.0215  max mem: 1931
# Test:  [200/648]  eta: 0:00:20  model_time: 0.0198 (0.0236)  evaluator_time: 0.0011 (0.0017)  time: 0.0332  data: 0.0102  max mem: 1931
# Test:  [300/648]  eta: 0:00:49  model_time: 0.0436 (0.0262)  evaluator_time: 0.0011 (0.0015)  time: 0.8613  data: 0.7516  max mem: 1931
# Test:  [400/648]  eta: 0:01:19  model_time: 0.0432 (0.0306)  evaluator_time: 0.0011 (0.0014)  time: 0.8592  data: 0.7512  max mem: 1931
# Test:  [500/648]  eta: 0:01:03  model_time: 0.0448 (0.0334)  evaluator_time: 0.0011 (0.0014)  time: 0.9034  data: 0.7934  max mem: 1931
# Test:  [600/648]  eta: 0:00:23  model_time: 0.0417 (0.0353)  evaluator_time: 0.0011 (0.0014)  time: 0.6786  data: 0.5878  max mem: 1931
# Test:  [647/648]  eta: 0:00:00  model_time: 0.0235 (0.0348)  evaluator_time: 0.0008 (0.0014)  time: 0.0324  data: 0.0068  max mem: 1931
# Test: Total time: 0:05:04 (0.4701 s / it)
# Averaged stats: model_time: 0.0235 (0.0348)  evaluator_time: 0.0008 (0.0014)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Epoch: [1]  [   0/1089]  eta: 0:28:58  lr: 0.001000  loss: 0.3263 (0.3263)  loss_classifier: 0.0929 (0.0929)  loss_box_reg: 0.0997 (0.0997)  loss_objectness: 0.1217 (0.1217)  loss_rpn_box_reg: 0.0120 (0.0120)  time: 1.5962  data: 1.2698  max mem: 1931
# Epoch: [1]  [  10/1089]  eta: 0:07:22  lr: 0.001000  loss: 0.2457 (0.3012)  loss_classifier: 0.0829 (0.0954)  loss_box_reg: 0.0997 (0.1098)  loss_objectness: 0.0383 (0.0586)  loss_rpn_box_reg: 0.0251 (0.0374)  time: 0.4104  data: 0.2073  max mem: 1931
# Epoch: [1]  [  20/1089]  eta: 0:06:07  lr: 0.001000  loss: 0.2885 (0.3463)  loss_classifier: 0.0818 (0.0962)  loss_box_reg: 0.0937 (0.1005)  loss_objectness: 0.0482 (0.0912)  loss_rpn_box_reg: 0.0313 (0.0584)  time: 0.2812  data: 0.1116  max mem: 1931
# Epoch: [1]  [  30/1089]  eta: 0:05:16  lr: 0.001000  loss: 0.3096 (0.3539)  loss_classifier: 0.0653 (0.1002)  loss_box_reg: 0.0759 (0.1087)  loss_objectness: 0.0896 (0.0809)  loss_rpn_box_reg: 0.0507 (0.0641)  time: 0.2381  data: 0.0998  max mem: 1931
# Epoch: [1]  [  40/1089]  eta: 0:04:40  lr: 0.001000  loss: 0.3096 (0.3858)  loss_classifier: 0.0945 (0.1060)  loss_box_reg: 0.0916 (0.1165)  loss_objectness: 0.0249 (0.0929)  loss_rpn_box_reg: 0.0295 (0.0704)  time: 0.1867  data: 0.0522  max mem: 1931
# Epoch: [1]  [  50/1089]  eta: 0:04:27  lr: 0.001000  loss: 0.3398 (0.3964)  loss_classifier: 0.0934 (0.1019)  loss_box_reg: 0.1048 (0.1165)  loss_objectness: 0.0498 (0.0941)  loss_rpn_box_reg: 0.0339 (0.0839)  time: 0.1932  data: 0.0443  max mem: 1931
# Epoch: [1]  [  60/1089]  eta: 0:04:48  lr: 0.001000  loss: 0.3666 (0.4323)  loss_classifier: 0.0706 (0.0980)  loss_box_reg: 0.1048 (0.1137)  loss_objectness: 0.1027 (0.1093)  loss_rpn_box_reg: 0.0463 (0.1113)  time: 0.3064  data: 0.1223  max mem: 1931
# Epoch: [1]  [  70/1089]  eta: 0:04:31  lr: 0.001000  loss: 0.3405 (0.4162)  loss_classifier: 0.0534 (0.0970)  loss_box_reg: 0.0656 (0.1095)  loss_objectness: 0.0912 (0.1062)  loss_rpn_box_reg: 0.0768 (0.1034)  time: 0.2901  data: 0.1034  max mem: 1931
# Epoch: [1]  [  80/1089]  eta: 0:04:37  lr: 0.001000  loss: 0.2688 (0.4007)  loss_classifier: 0.0694 (0.0948)  loss_box_reg: 0.0682 (0.1095)  loss_objectness: 0.0582 (0.1024)  loss_rpn_box_reg: 0.0273 (0.0940)  time: 0.2609  data: 0.0866  max mem: 1931
# Epoch: [1]  [  90/1089]  eta: 0:04:25  lr: 0.001000  loss: 0.2688 (0.4018)  loss_classifier: 0.0753 (0.0947)  loss_box_reg: 0.1236 (0.1098)  loss_objectness: 0.0582 (0.1033)  loss_rpn_box_reg: 0.0228 (0.0941)  time: 0.2605  data: 0.0902  max mem: 1931
# Epoch: [1]  [ 100/1089]  eta: 0:04:14  lr: 0.001000  loss: 0.3195 (0.3985)  loss_classifier: 0.0686 (0.0943)  loss_box_reg: 0.1081 (0.1098)  loss_objectness: 0.0684 (0.1042)  loss_rpn_box_reg: 0.0194 (0.0902)  time: 0.1869  data: 0.0412  max mem: 1931
# Epoch: [1]  [ 110/1089]  eta: 0:04:05  lr: 0.001000  loss: 0.2880 (0.3919)  loss_classifier: 0.0686 (0.0941)  loss_box_reg: 0.0909 (0.1102)  loss_objectness: 0.0698 (0.1005)  loss_rpn_box_reg: 0.0194 (0.0871)  time: 0.1854  data: 0.0369  max mem: 1931
# Epoch: [1]  [ 120/1089]  eta: 0:04:05  lr: 0.001000  loss: 0.2830 (0.3997)  loss_classifier: 0.0896 (0.0977)  loss_box_reg: 0.0909 (0.1132)  loss_objectness: 0.0643 (0.1025)  loss_rpn_box_reg: 0.0242 (0.0863)  time: 0.2328  data: 0.0684  max mem: 1931
# Epoch: [1]  [ 130/1089]  eta: 0:03:57  lr: 0.001000  loss: 0.2830 (0.3920)  loss_classifier: 0.0896 (0.0967)  loss_box_reg: 0.0904 (0.1121)  loss_objectness: 0.0764 (0.1010)  loss_rpn_box_reg: 0.0301 (0.0823)  time: 0.2309  data: 0.0781  max mem: 1931
# Epoch: [1]  [ 140/1089]  eta: 0:03:58  lr: 0.001000  loss: 0.2373 (0.3827)  loss_classifier: 0.0702 (0.0960)  loss_box_reg: 0.0744 (0.1116)  loss_objectness: 0.0423 (0.0967)  loss_rpn_box_reg: 0.0228 (0.0784)  time: 0.2342  data: 0.0713  max mem: 1931
# Epoch: [1]  [ 150/1089]  eta: 0:03:51  lr: 0.001000  loss: 0.2548 (0.3796)  loss_classifier: 0.0702 (0.0961)  loss_box_reg: 0.1061 (0.1118)  loss_objectness: 0.0337 (0.0945)  loss_rpn_box_reg: 0.0228 (0.0771)  time: 0.2408  data: 0.0714  max mem: 1931
# Epoch: [1]  [ 160/1089]  eta: 0:03:56  lr: 0.001000  loss: 0.2918 (0.3769)  loss_classifier: 0.1077 (0.0977)  loss_box_reg: 0.1061 (0.1133)  loss_objectness: 0.0316 (0.0920)  loss_rpn_box_reg: 0.0160 (0.0739)  time: 0.2826  data: 0.1189  max mem: 1931
# Epoch: [1]  [ 170/1089]  eta: 0:03:51  lr: 0.001000  loss: 0.2442 (0.3689)  loss_classifier: 0.0841 (0.0967)  loss_box_reg: 0.0888 (0.1118)  loss_objectness: 0.0294 (0.0887)  loss_rpn_box_reg: 0.0145 (0.0717)  time: 0.2914  data: 0.1263  max mem: 1931
# Epoch: [1]  [ 180/1089]  eta: 0:03:47  lr: 0.001000  loss: 0.2421 (0.3660)  loss_classifier: 0.0831 (0.0973)  loss_box_reg: 0.0888 (0.1114)  loss_objectness: 0.0274 (0.0869)  loss_rpn_box_reg: 0.0201 (0.0704)  time: 0.2131  data: 0.0697  max mem: 1931
# Epoch: [1]  [ 190/1089]  eta: 0:03:45  lr: 0.001000  loss: 0.2582 (0.3636)  loss_classifier: 0.0901 (0.0975)  loss_box_reg: 0.0922 (0.1117)  loss_objectness: 0.0274 (0.0859)  loss_rpn_box_reg: 0.0242 (0.0686)  time: 0.2405  data: 0.0961  max mem: 1931
# Epoch: [1]  [ 200/1089]  eta: 0:03:40  lr: 0.001000  loss: 0.2679 (0.3685)  loss_classifier: 0.0901 (0.0991)  loss_box_reg: 0.1007 (0.1124)  loss_objectness: 0.0373 (0.0890)  loss_rpn_box_reg: 0.0237 (0.0680)  time: 0.2249  data: 0.0698  max mem: 1931
# Epoch: [1]  [ 210/1089]  eta: 0:03:36  lr: 0.001000  loss: 0.3440 (0.3682)  loss_classifier: 0.0922 (0.0997)  loss_box_reg: 0.0815 (0.1122)  loss_objectness: 0.0565 (0.0892)  loss_rpn_box_reg: 0.0168 (0.0671)  time: 0.2059  data: 0.0588  max mem: 1931
# Epoch: [1]  [ 220/1089]  eta: 0:03:32  lr: 0.001000  loss: 0.2640 (0.3683)  loss_classifier: 0.0864 (0.0988)  loss_box_reg: 0.0773 (0.1108)  loss_objectness: 0.0557 (0.0921)  loss_rpn_box_reg: 0.0183 (0.0667)  time: 0.2107  data: 0.0683  max mem: 1931
# Epoch: [1]  [ 230/1089]  eta: 0:03:35  lr: 0.001000  loss: 0.2514 (0.3700)  loss_classifier: 0.0767 (0.0992)  loss_box_reg: 0.0661 (0.1099)  loss_objectness: 0.0535 (0.0929)  loss_rpn_box_reg: 0.0184 (0.0679)  time: 0.2935  data: 0.1219  max mem: 1931
# Epoch: [1]  [ 240/1089]  eta: 0:03:34  lr: 0.001000  loss: 0.3089 (0.3797)  loss_classifier: 0.1006 (0.0999)  loss_box_reg: 0.0661 (0.1100)  loss_objectness: 0.0792 (0.0953)  loss_rpn_box_reg: 0.0149 (0.0745)  time: 0.3417  data: 0.1489  max mem: 1931
# Epoch: [1]  [ 250/1089]  eta: 0:03:34  lr: 0.001000  loss: 0.3499 (0.3804)  loss_classifier: 0.1102 (0.1000)  loss_box_reg: 0.0841 (0.1097)  loss_objectness: 0.0703 (0.0958)  loss_rpn_box_reg: 0.0249 (0.0749)  time: 0.3059  data: 0.1319  max mem: 1931
# Epoch: [1]  [ 260/1089]  eta: 0:03:37  lr: 0.001000  loss: 0.3522 (0.3901)  loss_classifier: 0.0848 (0.0997)  loss_box_reg: 0.0955 (0.1099)  loss_objectness: 0.0643 (0.0976)  loss_rpn_box_reg: 0.0445 (0.0830)  time: 0.3785  data: 0.1821  max mem: 1931
# Epoch: [1]  [ 270/1089]  eta: 0:03:35  lr: 0.001000  loss: 0.3660 (0.3936)  loss_classifier: 0.0911 (0.1002)  loss_box_reg: 0.0814 (0.1093)  loss_objectness: 0.0924 (0.0990)  loss_rpn_box_reg: 0.0344 (0.0852)  time: 0.3609  data: 0.1583  max mem: 1931
# Epoch: [1]  [ 280/1089]  eta: 0:03:32  lr: 0.001000  loss: 0.4031 (0.3976)  loss_classifier: 0.1121 (0.1008)  loss_box_reg: 0.0814 (0.1102)  loss_objectness: 0.1107 (0.1007)  loss_rpn_box_reg: 0.0328 (0.0859)  time: 0.2748  data: 0.0979  max mem: 1931
# Epoch: [1]  [ 290/1089]  eta: 0:03:29  lr: 0.001000  loss: 0.3273 (0.3935)  loss_classifier: 0.0775 (0.1002)  loss_box_reg: 0.0953 (0.1098)  loss_objectness: 0.0632 (0.0997)  loss_rpn_box_reg: 0.0261 (0.0838)  time: 0.2462  data: 0.0866  max mem: 1931
# Epoch: [1]  [ 300/1089]  eta: 0:03:29  lr: 0.001000  loss: 0.2580 (0.3915)  loss_classifier: 0.0775 (0.1003)  loss_box_reg: 0.0953 (0.1105)  loss_objectness: 0.0457 (0.0986)  loss_rpn_box_reg: 0.0177 (0.0822)  time: 0.2947  data: 0.1425  max mem: 1931
# Epoch: [1]  [ 310/1089]  eta: 0:03:27  lr: 0.001000  loss: 0.3113 (0.3928)  loss_classifier: 0.1033 (0.1007)  loss_box_reg: 0.1003 (0.1106)  loss_objectness: 0.0627 (0.0985)  loss_rpn_box_reg: 0.0195 (0.0830)  time: 0.3255  data: 0.1403  max mem: 1931
# Epoch: [1]  [ 320/1089]  eta: 0:03:25  lr: 0.001000  loss: 0.3328 (0.3912)  loss_classifier: 0.0939 (0.1004)  loss_box_reg: 0.0837 (0.1096)  loss_objectness: 0.0653 (0.0990)  loss_rpn_box_reg: 0.0311 (0.0823)  time: 0.2960  data: 0.0916  max mem: 1931
# Epoch: [1]  [ 330/1089]  eta: 0:03:25  lr: 0.001000  loss: 0.3389 (0.4008)  loss_classifier: 0.0778 (0.1014)  loss_box_reg: 0.0711 (0.1094)  loss_objectness: 0.0757 (0.1029)  loss_rpn_box_reg: 0.0613 (0.0871)  time: 0.3399  data: 0.1504  max mem: 1931
# Epoch: [1]  [ 340/1089]  eta: 0:03:22  lr: 0.001000  loss: 0.4816 (0.4019)  loss_classifier: 0.0729 (0.1009)  loss_box_reg: 0.0759 (0.1093)  loss_objectness: 0.1211 (0.1038)  loss_rpn_box_reg: 0.1116 (0.0879)  time: 0.3343  data: 0.1699  max mem: 1931
# Epoch: [1]  [ 350/1089]  eta: 0:03:24  lr: 0.001000  loss: 0.3356 (0.3991)  loss_classifier: 0.0651 (0.1001)  loss_box_reg: 0.0759 (0.1087)  loss_objectness: 0.0921 (0.1038)  loss_rpn_box_reg: 0.0316 (0.0866)  time: 0.3830  data: 0.1976  max mem: 1931
# Epoch: [1]  [ 360/1089]  eta: 0:03:20  lr: 0.001000  loss: 0.3356 (0.4042)  loss_classifier: 0.0808 (0.1016)  loss_box_reg: 0.0917 (0.1107)  loss_objectness: 0.0767 (0.1053)  loss_rpn_box_reg: 0.0266 (0.0866)  time: 0.3417  data: 0.1499  max mem: 1931
# Epoch: [1]  [ 370/1089]  eta: 0:03:15  lr: 0.001000  loss: 0.4049 (0.4061)  loss_classifier: 0.1242 (0.1021)  loss_box_reg: 0.1338 (0.1114)  loss_objectness: 0.1016 (0.1065)  loss_rpn_box_reg: 0.0413 (0.0861)  time: 0.1906  data: 0.0335  max mem: 1931
# Epoch: [1]  [ 380/1089]  eta: 0:03:11  lr: 0.001000  loss: 0.3091 (0.4027)  loss_classifier: 0.0832 (0.1016)  loss_box_reg: 0.0808 (0.1107)  loss_objectness: 0.0585 (0.1055)  loss_rpn_box_reg: 0.0308 (0.0850)  time: 0.1891  data: 0.0364  max mem: 1931
# Epoch: [1]  [ 390/1089]  eta: 0:03:08  lr: 0.001000  loss: 0.2263 (0.3997)  loss_classifier: 0.0673 (0.1011)  loss_box_reg: 0.0808 (0.1108)  loss_objectness: 0.0447 (0.1037)  loss_rpn_box_reg: 0.0192 (0.0841)  time: 0.2294  data: 0.0757  max mem: 1931
# Epoch: [1]  [ 400/1089]  eta: 0:03:08  lr: 0.001000  loss: 0.2498 (0.3985)  loss_classifier: 0.0806 (0.1013)  loss_box_reg: 0.0983 (0.1107)  loss_objectness: 0.0438 (0.1033)  loss_rpn_box_reg: 0.0198 (0.0832)  time: 0.3363  data: 0.1681  max mem: 1931
# Epoch: [1]  [ 410/1089]  eta: 0:03:05  lr: 0.001000  loss: 0.2454 (0.3960)  loss_classifier: 0.0791 (0.1009)  loss_box_reg: 0.1096 (0.1110)  loss_objectness: 0.0489 (0.1020)  loss_rpn_box_reg: 0.0198 (0.0820)  time: 0.3362  data: 0.1652  max mem: 1931
# Epoch: [1]  [ 420/1089]  eta: 0:03:00  lr: 0.001000  loss: 0.2714 (0.3998)  loss_classifier: 0.0893 (0.1028)  loss_box_reg: 0.0819 (0.1129)  loss_objectness: 0.0497 (0.1023)  loss_rpn_box_reg: 0.0229 (0.0818)  time: 0.1982  data: 0.0562  max mem: 1931
# Epoch: [1]  [ 430/1089]  eta: 0:02:57  lr: 0.001000  loss: 0.3183 (0.3987)  loss_classifier: 0.1100 (0.1029)  loss_box_reg: 0.0775 (0.1126)  loss_objectness: 0.0623 (0.1021)  loss_rpn_box_reg: 0.0341 (0.0811)  time: 0.1859  data: 0.0447  max mem: 1931
# Epoch: [1]  [ 440/1089]  eta: 0:02:54  lr: 0.001000  loss: 0.3359 (0.3985)  loss_classifier: 0.0948 (0.1034)  loss_box_reg: 0.1084 (0.1131)  loss_objectness: 0.0623 (0.1017)  loss_rpn_box_reg: 0.0252 (0.0804)  time: 0.2331  data: 0.0851  max mem: 1931
# Epoch: [1]  [ 450/1089]  eta: 0:02:49  lr: 0.001000  loss: 0.2589 (0.3953)  loss_classifier: 0.0772 (0.1026)  loss_box_reg: 0.0804 (0.1130)  loss_objectness: 0.0414 (0.1004)  loss_rpn_box_reg: 0.0198 (0.0794)  time: 0.1853  data: 0.0537  max mem: 1931
# Epoch: [1]  [ 460/1089]  eta: 0:02:47  lr: 0.001000  loss: 0.2420 (0.3943)  loss_classifier: 0.0670 (0.1029)  loss_box_reg: 0.0794 (0.1130)  loss_objectness: 0.0283 (0.0999)  loss_rpn_box_reg: 0.0279 (0.0786)  time: 0.2196  data: 0.0752  max mem: 1931
# Epoch: [1]  [ 470/1089]  eta: 0:02:45  lr: 0.001000  loss: 0.2858 (0.3923)  loss_classifier: 0.0786 (0.1026)  loss_box_reg: 0.0676 (0.1121)  loss_objectness: 0.0653 (0.0998)  loss_rpn_box_reg: 0.0262 (0.0779)  time: 0.3148  data: 0.1345  max mem: 1931
# Epoch: [1]  [ 480/1089]  eta: 0:02:43  lr: 0.001000  loss: 0.2928 (0.3914)  loss_classifier: 0.0918 (0.1026)  loss_box_reg: 0.0886 (0.1126)  loss_objectness: 0.0636 (0.0993)  loss_rpn_box_reg: 0.0247 (0.0769)  time: 0.3291  data: 0.1555  max mem: 1931
# Epoch: [1]  [ 490/1089]  eta: 0:02:39  lr: 0.001000  loss: 0.2366 (0.3882)  loss_classifier: 0.0753 (0.1022)  loss_box_reg: 0.0886 (0.1124)  loss_objectness: 0.0295 (0.0979)  loss_rpn_box_reg: 0.0153 (0.0757)  time: 0.2489  data: 0.1047  max mem: 1931
# Epoch: [1]  [ 500/1089]  eta: 0:02:36  lr: 0.001000  loss: 0.2032 (0.3883)  loss_classifier: 0.0730 (0.1023)  loss_box_reg: 0.0878 (0.1129)  loss_objectness: 0.0322 (0.0976)  loss_rpn_box_reg: 0.0192 (0.0755)  time: 0.1996  data: 0.0596  max mem: 1931
# Epoch: [1]  [ 510/1089]  eta: 0:02:35  lr: 0.001000  loss: 0.3633 (0.3891)  loss_classifier: 0.1212 (0.1028)  loss_box_reg: 0.1458 (0.1140)  loss_objectness: 0.0408 (0.0973)  loss_rpn_box_reg: 0.0263 (0.0750)  time: 0.3206  data: 0.1347  max mem: 1931
# Epoch: [1]  [ 520/1089]  eta: 0:02:31  lr: 0.001000  loss: 0.3491 (0.3874)  loss_classifier: 0.1003 (0.1028)  loss_box_reg: 0.1127 (0.1141)  loss_objectness: 0.0362 (0.0961)  loss_rpn_box_reg: 0.0213 (0.0744)  time: 0.2704  data: 0.0974  max mem: 1931
# Epoch: [1]  [ 530/1089]  eta: 0:02:28  lr: 0.001000  loss: 0.3330 (0.3872)  loss_classifier: 0.0961 (0.1029)  loss_box_reg: 0.1127 (0.1150)  loss_objectness: 0.0287 (0.0952)  loss_rpn_box_reg: 0.0213 (0.0741)  time: 0.1955  data: 0.0552  max mem: 1931
# Epoch: [1]  [ 540/1089]  eta: 0:02:26  lr: 0.001000  loss: 0.2821 (0.3884)  loss_classifier: 0.0853 (0.1029)  loss_box_reg: 0.1089 (0.1149)  loss_objectness: 0.0384 (0.0956)  loss_rpn_box_reg: 0.0181 (0.0750)  time: 0.2589  data: 0.0996  max mem: 1931
# Epoch: [1]  [ 550/1089]  eta: 0:02:23  lr: 0.001000  loss: 0.3183 (0.3928)  loss_classifier: 0.0953 (0.1039)  loss_box_reg: 0.0946 (0.1156)  loss_objectness: 0.0652 (0.0969)  loss_rpn_box_reg: 0.0203 (0.0765)  time: 0.2718  data: 0.1064  max mem: 1931
# Epoch: [1]  [ 560/1089]  eta: 0:02:21  lr: 0.001000  loss: 0.2659 (0.3906)  loss_classifier: 0.0809 (0.1035)  loss_box_reg: 0.0833 (0.1156)  loss_objectness: 0.0446 (0.0960)  loss_rpn_box_reg: 0.0259 (0.0755)  time: 0.2857  data: 0.0999  max mem: 1931
# Epoch: [1]  [ 570/1089]  eta: 0:02:19  lr: 0.001000  loss: 0.2506 (0.3895)  loss_classifier: 0.0645 (0.1033)  loss_box_reg: 0.0833 (0.1156)  loss_objectness: 0.0348 (0.0958)  loss_rpn_box_reg: 0.0259 (0.0749)  time: 0.3314  data: 0.1430  max mem: 1931
# Epoch: [1]  [ 580/1089]  eta: 0:02:16  lr: 0.001000  loss: 0.3420 (0.3895)  loss_classifier: 0.0787 (0.1029)  loss_box_reg: 0.0577 (0.1149)  loss_objectness: 0.0604 (0.0962)  loss_rpn_box_reg: 0.0344 (0.0754)  time: 0.2885  data: 0.1298  max mem: 1931
# Epoch: [1]  [ 590/1089]  eta: 0:02:13  lr: 0.001000  loss: 0.3032 (0.3893)  loss_classifier: 0.0747 (0.1025)  loss_box_reg: 0.0573 (0.1143)  loss_objectness: 0.0747 (0.0962)  loss_rpn_box_reg: 0.0364 (0.0762)  time: 0.2242  data: 0.0733  max mem: 1931
# Epoch: [1]  [ 600/1089]  eta: 0:02:10  lr: 0.001000  loss: 0.3498 (0.3912)  loss_classifier: 0.0762 (0.1026)  loss_box_reg: 0.0867 (0.1151)  loss_objectness: 0.0724 (0.0966)  loss_rpn_box_reg: 0.0364 (0.0768)  time: 0.2213  data: 0.0700  max mem: 1931
# Epoch: [1]  [ 610/1089]  eta: 0:02:08  lr: 0.001000  loss: 0.3865 (0.3918)  loss_classifier: 0.1077 (0.1029)  loss_box_reg: 0.1360 (0.1159)  loss_objectness: 0.0618 (0.0964)  loss_rpn_box_reg: 0.0380 (0.0765)  time: 0.2839  data: 0.1154  max mem: 1931
# Epoch: [1]  [ 620/1089]  eta: 0:02:05  lr: 0.001000  loss: 0.3763 (0.3923)  loss_classifier: 0.0912 (0.1028)  loss_box_reg: 0.1327 (0.1158)  loss_objectness: 0.0489 (0.0966)  loss_rpn_box_reg: 0.0279 (0.0772)  time: 0.2879  data: 0.1178  max mem: 1931
# Epoch: [1]  [ 630/1089]  eta: 0:02:02  lr: 0.001000  loss: 0.2892 (0.3915)  loss_classifier: 0.0800 (0.1025)  loss_box_reg: 0.0857 (0.1155)  loss_objectness: 0.0677 (0.0967)  loss_rpn_box_reg: 0.0299 (0.0768)  time: 0.2771  data: 0.1083  max mem: 1931
# Epoch: [1]  [ 640/1089]  eta: 0:01:59  lr: 0.001000  loss: 0.3666 (0.3929)  loss_classifier: 0.0973 (0.1029)  loss_box_reg: 0.0897 (0.1159)  loss_objectness: 0.0677 (0.0973)  loss_rpn_box_reg: 0.0299 (0.0768)  time: 0.2785  data: 0.1106  max mem: 1931
# Epoch: [1]  [ 650/1089]  eta: 0:01:56  lr: 0.001000  loss: 0.3644 (0.3929)  loss_classifier: 0.1033 (0.1031)  loss_box_reg: 0.1038 (0.1159)  loss_objectness: 0.1040 (0.0977)  loss_rpn_box_reg: 0.0215 (0.0762)  time: 0.2134  data: 0.0710  max mem: 1931
# Epoch: [1]  [ 660/1089]  eta: 0:01:54  lr: 0.001000  loss: 0.2798 (0.3917)  loss_classifier: 0.0900 (0.1029)  loss_box_reg: 0.0859 (0.1155)  loss_objectness: 0.0797 (0.0972)  loss_rpn_box_reg: 0.0183 (0.0760)  time: 0.2837  data: 0.1139  max mem: 1931
# Epoch: [1]  [ 670/1089]  eta: 0:01:51  lr: 0.001000  loss: 0.2542 (0.3908)  loss_classifier: 0.0809 (0.1027)  loss_box_reg: 0.0859 (0.1156)  loss_objectness: 0.0360 (0.0969)  loss_rpn_box_reg: 0.0183 (0.0756)  time: 0.2648  data: 0.0941  max mem: 1931
# Epoch: [1]  [ 680/1089]  eta: 0:01:48  lr: 0.001000  loss: 0.3079 (0.3896)  loss_classifier: 0.0825 (0.1027)  loss_box_reg: 0.1165 (0.1154)  loss_objectness: 0.0483 (0.0965)  loss_rpn_box_reg: 0.0204 (0.0751)  time: 0.1947  data: 0.0485  max mem: 1931
# Epoch: [1]  [ 690/1089]  eta: 0:01:45  lr: 0.001000  loss: 0.2716 (0.3885)  loss_classifier: 0.1159 (0.1030)  loss_box_reg: 0.0898 (0.1153)  loss_objectness: 0.0483 (0.0958)  loss_rpn_box_reg: 0.0174 (0.0744)  time: 0.2014  data: 0.0562  max mem: 1931
# ...
# Epoch: [4]  [ 560/1089]  eta: 0:02:17  lr: 0.000100  loss: 0.3047 (0.3247)  loss_classifier: 0.1176 (0.1042)  loss_box_reg: 0.1233 (0.1106)  loss_objectness: 0.0276 (0.0578)  loss_rpn_box_reg: 0.0163 (0.0521)  time: 0.2744  data: 0.1146  max mem: 1931
# Epoch: [4]  [ 570/1089]  eta: 0:02:14  lr: 0.000100  loss: 0.2978 (0.3258)  loss_classifier: 0.0861 (0.1043)  loss_box_reg: 0.1012 (0.1106)  loss_objectness: 0.0408 (0.0581)  loss_rpn_box_reg: 0.0118 (0.0528)  time: 0.2685  data: 0.1165  max mem: 1931
# Epoch: [4]  [ 580/1089]  eta: 0:02:11  lr: 0.000100  loss: 0.3072 (0.3264)  loss_classifier: 0.1006 (0.1047)  loss_box_reg: 0.1012 (0.1110)  loss_objectness: 0.0408 (0.0578)  loss_rpn_box_reg: 0.0331 (0.0528)  time: 0.1892  data: 0.0532  max mem: 1931
# Epoch: [4]  [ 590/1089]  eta: 0:02:08  lr: 0.000100  loss: 0.3235 (0.3259)  loss_classifier: 0.0895 (0.1045)  loss_box_reg: 0.0921 (0.1104)  loss_objectness: 0.0323 (0.0584)  loss_rpn_box_reg: 0.0340 (0.0527)  time: 0.1762  data: 0.0319  max mem: 1931
# Epoch: [4]  [ 600/1089]  eta: 0:02:06  lr: 0.000100  loss: 0.3235 (0.3253)  loss_classifier: 0.0802 (0.1044)  loss_box_reg: 0.0848 (0.1103)  loss_objectness: 0.0288 (0.0582)  loss_rpn_box_reg: 0.0303 (0.0524)  time: 0.3230  data: 0.1398  max mem: 1931
# Epoch: [4]  [ 610/1089]  eta: 0:02:03  lr: 0.000100  loss: 0.3624 (0.3277)  loss_classifier: 0.1235 (0.1049)  loss_box_reg: 0.1044 (0.1105)  loss_objectness: 0.0559 (0.0594)  loss_rpn_box_reg: 0.0311 (0.0528)  time: 0.3132  data: 0.1449  max mem: 1931
# Epoch: [4]  [ 620/1089]  eta: 0:02:01  lr: 0.000100  loss: 0.3354 (0.3274)  loss_classifier: 0.1037 (0.1052)  loss_box_reg: 0.0905 (0.1104)  loss_objectness: 0.0984 (0.0594)  loss_rpn_box_reg: 0.0273 (0.0523)  time: 0.2508  data: 0.0974  max mem: 1931
# Epoch: [4]  [ 630/1089]  eta: 0:01:59  lr: 0.000100  loss: 0.2833 (0.3265)  loss_classifier: 0.0935 (0.1049)  loss_box_reg: 0.0887 (0.1103)  loss_objectness: 0.0272 (0.0592)  loss_rpn_box_reg: 0.0162 (0.0522)  time: 0.3260  data: 0.1293  max mem: 1931
# Epoch: [4]  [ 640/1089]  eta: 0:01:57  lr: 0.000100  loss: 0.2783 (0.3262)  loss_classifier: 0.0919 (0.1050)  loss_box_reg: 0.1089 (0.1106)  loss_objectness: 0.0219 (0.0590)  loss_rpn_box_reg: 0.0154 (0.0516)  time: 0.3374  data: 0.1309  max mem: 1931
# Epoch: [4]  [ 650/1089]  eta: 0:01:55  lr: 0.000100  loss: 0.2998 (0.3286)  loss_classifier: 0.1083 (0.1055)  loss_box_reg: 0.1217 (0.1115)  loss_objectness: 0.0423 (0.0591)  loss_rpn_box_reg: 0.0264 (0.0525)  time: 0.3153  data: 0.1415  max mem: 1931
# Epoch: [4]  [ 660/1089]  eta: 0:01:52  lr: 0.000100  loss: 0.2990 (0.3287)  loss_classifier: 0.1138 (0.1056)  loss_box_reg: 0.0965 (0.1117)  loss_objectness: 0.0412 (0.0591)  loss_rpn_box_reg: 0.0315 (0.0523)  time: 0.2513  data: 0.1017  max mem: 1931
# Epoch: [4]  [ 670/1089]  eta: 0:01:49  lr: 0.000100  loss: 0.2634 (0.3282)  loss_classifier: 0.0939 (0.1057)  loss_box_reg: 0.0848 (0.1118)  loss_objectness: 0.0305 (0.0589)  loss_rpn_box_reg: 0.0111 (0.0517)  time: 0.2267  data: 0.0774  max mem: 1931
# Epoch: [4]  [ 680/1089]  eta: 0:01:46  lr: 0.000100  loss: 0.2443 (0.3287)  loss_classifier: 0.0950 (0.1058)  loss_box_reg: 0.0848 (0.1118)  loss_objectness: 0.0408 (0.0593)  loss_rpn_box_reg: 0.0121 (0.0518)  time: 0.2315  data: 0.0824  max mem: 1931
# Epoch: [4]  [ 690/1089]  eta: 0:01:44  lr: 0.000100  loss: 0.2482 (0.3280)  loss_classifier: 0.0859 (0.1055)  loss_box_reg: 0.1096 (0.1116)  loss_objectness: 0.0262 (0.0591)  loss_rpn_box_reg: 0.0121 (0.0518)  time: 0.2830  data: 0.0854  max mem: 1931
# Epoch: [4]  [ 700/1089]  eta: 0:01:41  lr: 0.000100  loss: 0.2482 (0.3274)  loss_classifier: 0.0814 (0.1053)  loss_box_reg: 0.1002 (0.1113)  loss_objectness: 0.0235 (0.0591)  loss_rpn_box_reg: 0.0169 (0.0517)  time: 0.3172  data: 0.1065  max mem: 1931
# Epoch: [4]  [ 710/1089]  eta: 0:01:39  lr: 0.000100  loss: 0.1936 (0.3268)  loss_classifier: 0.0814 (0.1048)  loss_box_reg: 0.0733 (0.1107)  loss_objectness: 0.0218 (0.0590)  loss_rpn_box_reg: 0.0150 (0.0522)  time: 0.2970  data: 0.1401  max mem: 1931
# Epoch: [4]  [ 720/1089]  eta: 0:01:37  lr: 0.000100  loss: 0.1936 (0.3268)  loss_classifier: 0.0890 (0.1050)  loss_box_reg: 0.0742 (0.1108)  loss_objectness: 0.0250 (0.0592)  loss_rpn_box_reg: 0.0129 (0.0518)  time: 0.2880  data: 0.1452  max mem: 1931
# Epoch: [4]  [ 730/1089]  eta: 0:01:33  lr: 0.000100  loss: 0.2934 (0.3274)  loss_classifier: 0.1181 (0.1052)  loss_box_reg: 0.0862 (0.1110)  loss_objectness: 0.0591 (0.0595)  loss_rpn_box_reg: 0.0168 (0.0517)  time: 0.2232  data: 0.0842  max mem: 1931
# Epoch: [4]  [ 740/1089]  eta: 0:01:31  lr: 0.000100  loss: 0.3404 (0.3281)  loss_classifier: 0.1134 (0.1054)  loss_box_reg: 0.1153 (0.1112)  loss_objectness: 0.0534 (0.0596)  loss_rpn_box_reg: 0.0217 (0.0519)  time: 0.2795  data: 0.1027  max mem: 1931
# Epoch: [4]  [ 750/1089]  eta: 0:01:29  lr: 0.000100  loss: 0.2571 (0.3273)  loss_classifier: 0.1090 (0.1052)  loss_box_reg: 0.1027 (0.1110)  loss_objectness: 0.0327 (0.0595)  loss_rpn_box_reg: 0.0159 (0.0516)  time: 0.3378  data: 0.1350  max mem: 1931
# Epoch: [4]  [ 760/1089]  eta: 0:01:26  lr: 0.000100  loss: 0.2571 (0.3290)  loss_classifier: 0.0959 (0.1055)  loss_box_reg: 0.0940 (0.1117)  loss_objectness: 0.0318 (0.0598)  loss_rpn_box_reg: 0.0186 (0.0519)  time: 0.2926  data: 0.1169  max mem: 1931
# Epoch: [4]  [ 770/1089]  eta: 0:01:24  lr: 0.000100  loss: 0.3199 (0.3284)  loss_classifier: 0.0993 (0.1055)  loss_box_reg: 0.1148 (0.1117)  loss_objectness: 0.0291 (0.0597)  loss_rpn_box_reg: 0.0237 (0.0515)  time: 0.2733  data: 0.1036  max mem: 1931
# Epoch: [4]  [ 780/1089]  eta: 0:01:21  lr: 0.000100  loss: 0.2655 (0.3283)  loss_classifier: 0.0916 (0.1057)  loss_box_reg: 0.0982 (0.1119)  loss_objectness: 0.0201 (0.0594)  loss_rpn_box_reg: 0.0173 (0.0512)  time: 0.2513  data: 0.0941  max mem: 1931
# Epoch: [4]  [ 790/1089]  eta: 0:01:19  lr: 0.000100  loss: 0.2822 (0.3287)  loss_classifier: 0.0837 (0.1058)  loss_box_reg: 0.0904 (0.1119)  loss_objectness: 0.0357 (0.0598)  loss_rpn_box_reg: 0.0173 (0.0512)  time: 0.3164  data: 0.1591  max mem: 1931
# Epoch: [4]  [ 800/1089]  eta: 0:01:16  lr: 0.000100  loss: 0.2939 (0.3286)  loss_classifier: 0.0830 (0.1057)  loss_box_reg: 0.0904 (0.1120)  loss_objectness: 0.0430 (0.0599)  loss_rpn_box_reg: 0.0220 (0.0510)  time: 0.3054  data: 0.1389  max mem: 1931
# Epoch: [4]  [ 810/1089]  eta: 0:01:14  lr: 0.000100  loss: 0.3110 (0.3281)  loss_classifier: 0.0733 (0.1054)  loss_box_reg: 0.0630 (0.1116)  loss_objectness: 0.0716 (0.0600)  loss_rpn_box_reg: 0.0315 (0.0511)  time: 0.2841  data: 0.1139  max mem: 1931
# Epoch: [4]  [ 820/1089]  eta: 0:01:11  lr: 0.000100  loss: 0.3015 (0.3277)  loss_classifier: 0.0965 (0.1054)  loss_box_reg: 0.0661 (0.1113)  loss_objectness: 0.0484 (0.0599)  loss_rpn_box_reg: 0.0349 (0.0510)  time: 0.2372  data: 0.0889  max mem: 1931
# Epoch: [4]  [ 830/1089]  eta: 0:01:08  lr: 0.000100  loss: 0.2678 (0.3283)  loss_classifier: 0.0961 (0.1052)  loss_box_reg: 0.0787 (0.1111)  loss_objectness: 0.0472 (0.0604)  loss_rpn_box_reg: 0.0224 (0.0517)  time: 0.1886  data: 0.0572  max mem: 1931
# Epoch: [4]  [ 840/1089]  eta: 0:01:05  lr: 0.000100  loss: 0.2234 (0.3273)  loss_classifier: 0.0866 (0.1050)  loss_box_reg: 0.0923 (0.1110)  loss_objectness: 0.0145 (0.0600)  loss_rpn_box_reg: 0.0148 (0.0512)  time: 0.2720  data: 0.1172  max mem: 1931
# Epoch: [4]  [ 850/1089]  eta: 0:01:03  lr: 0.000100  loss: 0.2183 (0.3278)  loss_classifier: 0.0704 (0.1048)  loss_box_reg: 0.0923 (0.1109)  loss_objectness: 0.0175 (0.0603)  loss_rpn_box_reg: 0.0162 (0.0518)  time: 0.2669  data: 0.1081  max mem: 1931
# Epoch: [4]  [ 860/1089]  eta: 0:01:00  lr: 0.000100  loss: 0.2001 (0.3282)  loss_classifier: 0.0757 (0.1052)  loss_box_reg: 0.1065 (0.1114)  loss_objectness: 0.0315 (0.0602)  loss_rpn_box_reg: 0.0162 (0.0514)  time: 0.2186  data: 0.0716  max mem: 1931
# Epoch: [4]  [ 870/1089]  eta: 0:00:57  lr: 0.000100  loss: 0.2001 (0.3266)  loss_classifier: 0.0690 (0.1048)  loss_box_reg: 0.0807 (0.1110)  loss_objectness: 0.0135 (0.0597)  loss_rpn_box_reg: 0.0128 (0.0510)  time: 0.1694  data: 0.0385  max mem: 1931
# Epoch: [4]  [ 880/1089]  eta: 0:00:54  lr: 0.000100  loss: 0.2231 (0.3269)  loss_classifier: 0.0703 (0.1051)  loss_box_reg: 0.0771 (0.1111)  loss_objectness: 0.0431 (0.0600)  loss_rpn_box_reg: 0.0168 (0.0508)  time: 0.1641  data: 0.0345  max mem: 1931
# Epoch: [4]  [ 890/1089]  eta: 0:00:51  lr: 0.000100  loss: 0.3159 (0.3264)  loss_classifier: 0.1002 (0.1049)  loss_box_reg: 0.0728 (0.1109)  loss_objectness: 0.0605 (0.0599)  loss_rpn_box_reg: 0.0219 (0.0508)  time: 0.1731  data: 0.0393  max mem: 1931
# Epoch: [4]  [ 900/1089]  eta: 0:00:49  lr: 0.000100  loss: 0.3159 (0.3267)  loss_classifier: 0.0711 (0.1050)  loss_box_reg: 0.0693 (0.1113)  loss_objectness: 0.0351 (0.0599)  loss_rpn_box_reg: 0.0238 (0.0505)  time: 0.2322  data: 0.0892  max mem: 1931
# Epoch: [4]  [ 910/1089]  eta: 0:00:46  lr: 0.000100  loss: 0.2959 (0.3263)  loss_classifier: 0.0912 (0.1050)  loss_box_reg: 0.1052 (0.1114)  loss_objectness: 0.0296 (0.0596)  loss_rpn_box_reg: 0.0203 (0.0503)  time: 0.2831  data: 0.1321  max mem: 1931
# Epoch: [4]  [ 920/1089]  eta: 0:00:43  lr: 0.000100  loss: 0.2679 (0.3261)  loss_classifier: 0.0912 (0.1051)  loss_box_reg: 0.1099 (0.1115)  loss_objectness: 0.0252 (0.0593)  loss_rpn_box_reg: 0.0154 (0.0502)  time: 0.2206  data: 0.0774  max mem: 1931
# Epoch: [4]  [ 930/1089]  eta: 0:00:41  lr: 0.000100  loss: 0.2597 (0.3253)  loss_classifier: 0.0834 (0.1050)  loss_box_reg: 0.0848 (0.1111)  loss_objectness: 0.0252 (0.0593)  loss_rpn_box_reg: 0.0208 (0.0500)  time: 0.1826  data: 0.0415  max mem: 1931
# Epoch: [4]  [ 940/1089]  eta: 0:00:38  lr: 0.000100  loss: 0.2347 (0.3251)  loss_classifier: 0.0775 (0.1048)  loss_box_reg: 0.0574 (0.1108)  loss_objectness: 0.0275 (0.0592)  loss_rpn_box_reg: 0.0183 (0.0503)  time: 0.1633  data: 0.0289  max mem: 1931
# Epoch: [4]  [ 950/1089]  eta: 0:00:35  lr: 0.000100  loss: 0.2351 (0.3251)  loss_classifier: 0.0840 (0.1049)  loss_box_reg: 0.0783 (0.1111)  loss_objectness: 0.0223 (0.0589)  loss_rpn_box_reg: 0.0138 (0.0501)  time: 0.2123  data: 0.0549  max mem: 1931
# Epoch: [4]  [ 960/1089]  eta: 0:00:33  lr: 0.000100  loss: 0.1832 (0.3238)  loss_classifier: 0.0729 (0.1044)  loss_box_reg: 0.0781 (0.1107)  loss_objectness: 0.0185 (0.0586)  loss_rpn_box_reg: 0.0159 (0.0501)  time: 0.2566  data: 0.0892  max mem: 1931
# Epoch: [4]  [ 970/1089]  eta: 0:00:30  lr: 0.000100  loss: 0.1860 (0.3236)  loss_classifier: 0.0700 (0.1044)  loss_box_reg: 0.0605 (0.1105)  loss_objectness: 0.0113 (0.0587)  loss_rpn_box_reg: 0.0159 (0.0501)  time: 0.2388  data: 0.0878  max mem: 1931
# Epoch: [4]  [ 980/1089]  eta: 0:00:28  lr: 0.000100  loss: 0.2559 (0.3239)  loss_classifier: 0.0780 (0.1046)  loss_box_reg: 0.0878 (0.1111)  loss_objectness: 0.0267 (0.0584)  loss_rpn_box_reg: 0.0163 (0.0498)  time: 0.2323  data: 0.0809  max mem: 1931
# Epoch: [4]  [ 990/1089]  eta: 0:00:25  lr: 0.000100  loss: 0.2559 (0.3236)  loss_classifier: 0.0780 (0.1045)  loss_box_reg: 0.1018 (0.1111)  loss_objectness: 0.0256 (0.0582)  loss_rpn_box_reg: 0.0128 (0.0498)  time: 0.2222  data: 0.0601  max mem: 1931
# Epoch: [4]  [1000/1089]  eta: 0:00:22  lr: 0.000100  loss: 0.2459 (0.3231)  loss_classifier: 0.0689 (0.1044)  loss_box_reg: 0.0945 (0.1111)  loss_objectness: 0.0165 (0.0579)  loss_rpn_box_reg: 0.0111 (0.0497)  time: 0.1731  data: 0.0294  max mem: 1931
# Epoch: [4]  [1010/1089]  eta: 0:00:20  lr: 0.000100  loss: 0.3335 (0.3240)  loss_classifier: 0.0878 (0.1046)  loss_box_reg: 0.0945 (0.1111)  loss_objectness: 0.0313 (0.0584)  loss_rpn_box_reg: 0.0154 (0.0499)  time: 0.1448  data: 0.0236  max mem: 1931
# Epoch: [4]  [1020/1089]  eta: 0:00:17  lr: 0.000100  loss: 0.2698 (0.3234)  loss_classifier: 0.0878 (0.1046)  loss_box_reg: 0.0766 (0.1107)  loss_objectness: 0.0437 (0.0585)  loss_rpn_box_reg: 0.0121 (0.0496)  time: 0.2487  data: 0.1098  max mem: 1931
# Epoch: [4]  [1030/1089]  eta: 0:00:15  lr: 0.000100  loss: 0.2072 (0.3232)  loss_classifier: 0.0840 (0.1046)  loss_box_reg: 0.0897 (0.1108)  loss_objectness: 0.0352 (0.0584)  loss_rpn_box_reg: 0.0113 (0.0494)  time: 0.3172  data: 0.1651  max mem: 1931
# Epoch: [4]  [1040/1089]  eta: 0:00:12  lr: 0.000100  loss: 0.2901 (0.3231)  loss_classifier: 0.0840 (0.1045)  loss_box_reg: 0.1078 (0.1110)  loss_objectness: 0.0338 (0.0583)  loss_rpn_box_reg: 0.0191 (0.0494)  time: 0.2458  data: 0.0982  max mem: 1931
# Epoch: [4]  [1050/1089]  eta: 0:00:09  lr: 0.000100  loss: 0.3018 (0.3230)  loss_classifier: 0.0942 (0.1045)  loss_box_reg: 0.1428 (0.1113)  loss_objectness: 0.0162 (0.0580)  loss_rpn_box_reg: 0.0165 (0.0491)  time: 0.2462  data: 0.0864  max mem: 1931
# Epoch: [4]  [1060/1089]  eta: 0:00:07  lr: 0.000100  loss: 0.2936 (0.3230)  loss_classifier: 0.0947 (0.1047)  loss_box_reg: 0.1261 (0.1114)  loss_objectness: 0.0296 (0.0579)  loss_rpn_box_reg: 0.0157 (0.0489)  time: 0.2475  data: 0.0864  max mem: 1931
# Epoch: [4]  [1070/1089]  eta: 0:00:04  lr: 0.000100  loss: 0.2225 (0.3223)  loss_classifier: 0.0889 (0.1047)  loss_box_reg: 0.0964 (0.1114)  loss_objectness: 0.0320 (0.0577)  loss_rpn_box_reg: 0.0112 (0.0486)  time: 0.2439  data: 0.0834  max mem: 1931
# Epoch: [4]  [1080/1089]  eta: 0:00:02  lr: 0.000100  loss: 0.2898 (0.3228)  loss_classifier: 0.0890 (0.1049)  loss_box_reg: 0.1051 (0.1119)  loss_objectness: 0.0350 (0.0576)  loss_rpn_box_reg: 0.0172 (0.0485)  time: 0.3757  data: 0.1779  max mem: 1931
# Epoch: [4]  [1088/1089]  eta: 0:00:00  lr: 0.000100  loss: 0.3111 (0.3234)  loss_classifier: 0.1254 (0.1050)  loss_box_reg: 0.1226 (0.1122)  loss_objectness: 0.0390 (0.0577)  loss_rpn_box_reg: 0.0366 (0.0485)  time: 0.3713  data: 0.1782  max mem: 1931
# Epoch: [4] Total time: 0:04:40 (0.2578 s / it)
# creating index...
# index created!
# Test:  [  0/648]  eta: 0:00:26  model_time: 0.0340 (0.0340)  evaluator_time: 0.0015 (0.0015)  time: 0.0408  data: 0.0045  max mem: 1931
# Test:  [100/648]  eta: 0:00:18  model_time: 0.0209 (0.0222)  evaluator_time: 0.0010 (0.0012)  time: 0.0480  data: 0.0220  max mem: 1931
# Test:  [200/648]  eta: 0:00:18  model_time: 0.0195 (0.0218)  evaluator_time: 0.0010 (0.0013)  time: 0.0336  data: 0.0110  max mem: 1931
# Test:  [300/648]  eta: 0:00:48  model_time: 0.0402 (0.0248)  evaluator_time: 0.0011 (0.0014)  time: 0.8539  data: 0.7476  max mem: 1931
# Test:  [400/648]  eta: 0:01:18  model_time: 0.0412 (0.0290)  evaluator_time: 0.0011 (0.0013)  time: 0.8637  data: 0.7571  max mem: 1931
# Test:  [500/648]  eta: 0:01:02  model_time: 0.0429 (0.0317)  evaluator_time: 0.0011 (0.0013)  time: 0.8388  data: 0.7315  max mem: 1931
# Test:  [600/648]  eta: 0:00:23  model_time: 0.0388 (0.0333)  evaluator_time: 0.0011 (0.0013)  time: 0.6717  data: 0.5825  max mem: 1931
# Test:  [647/648]  eta: 0:00:00  model_time: 0.0230 (0.0329)  evaluator_time: 0.0010 (0.0013)  time: 0.0317  data: 0.0066  max mem: 1931
# Test: Total time: 0:04:57 (0.4593 s / it)
# Averaged stats: model_time: 0.0230 (0.0329)  evaluator_time: 0.0010 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.468
# Mounted at /content/drive/
